# %% [markdown]
# # BaseDataset inherit (Jacky)

# %% [markdown]
# # Dataset Tests (Ethan)

# %% [markdown]
# # BaseTask inherit (Ethan)

# %% [markdown]
# # Task Tests (Jacky)

# %% [markdown]
# # Ablations (Seb)

# %%
# Out:
# array([1, 2, 3])

# %%
from pyhealth.datasets import RESPectCCEPDataset
from pyhealth.datasets import split_by_patient, get_dataloader
from pyhealth.tasks import SeizureOnsetZoneLocalisation

# dataset = RESPectCCEPDataset(root="/path/to/ds004080/")
# # task = SeizureOnsetZoneLocalisation()
# # samples = dataset.set_task(task)
# # samples[0]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 from pyhealth.datasets import RESPectCCEPDataset
#       2 from pyhealth.datasets import split_by_patient, get_dataloader
#       3 from pyhealth.tasks import SeizureOnsetZoneLocalisation
#
# File c:\Users\ethan\OneDrive\Desktop\UIUC\CS 598\PyHealth-Localising-SOZ\pyhealth\datasets\__init__.py:49
#      41         import warnings
#      43         warnings.warn(
#      44             "The SampleSignalDataset class is deprecated and will be removed in a future version.",
#      45             DeprecationWarning,
#      46         )
# ---> 49 from .base_dataset import BaseDataset
#      50 from .cardiology import CardiologyDataset
#      51 from .chestxray14 import ChestXray14Dataset
#
# File c:\Users\ethan\OneDrive\Desktop\UIUC\CS 598\PyHealth-Localising-SOZ\pyhealth\datasets\base_dataset.py:18
#      15 import multiprocessing.queues
#      16 import shutil
# ---> 18 import litdata
#      19 from litdata.streaming.item_loader import ParquetLoader
#      20 from litdata.processing.data_processor import in_notebook
#
# File c:\Users\ethan\AppData\Local\Programs\Python\Python310\lib\site-packages\litdata\__init__.py:16
#      13 import warnings
#      15 from litdata.__about__ import *  # noqa: F403
# ---> 16 from litdata.constants import _LIGHTNING_SDK_AVAILABLE
#      17 from litdata.processing.functions import map, merge_datasets, optimize, walk
#      18 from litdata.raw.dataset import StreamingRawDataset
#
# File c:\Users\ethan\AppData\Local\Programs\Python\Python310\lib\site-packages\litdata\constants.py:19
#      16 from pathlib import Path
#      18 import numpy as np
# ---> 19 import torch
#      20 from lightning_utilities.core.imports import RequirementCache
#      22 _INDEX_FILENAME = "index.json"
#
# File c:\Users\ethan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:285
#     281                     raise err
#     283         kernel32.SetErrorMode(prev_error_mode)
# --> 285     _load_dll_libraries()
#     286     del _load_dll_libraries
#     289 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     290     # Libraries can either be in
#     291     # path/nvidia/lib_folder/lib or
#     292     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     293     # path/lib_folder/lib
#
# File c:\Users\ethan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:268, in _load_dll_libraries()
#     264     err = ctypes.WinError(last_error)
#     265     err.strerror += (
#     266         f' Error loading "{dll}" or one of its dependencies.'
#     267     )
# --> 268     raise err
#     269 elif res is not None:
#     270     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\ethan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
train_ds, val_ds, test_ds = split_by_patient(samples, [0.8, 0.1, 0.1])
train_loader = get_dataloader(train_ds, batch_size=16, shuffle=True)
