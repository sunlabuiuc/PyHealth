# %% [markdown]
# # SparcNet Smoke Test (PyHealth 2.0)
#
# This notebook uses the built-in `SleepEDFDataset` and `SleepStagingSleepEDF` task to load a small local `SleepEDF_demo` folder and run a forward-pass smoke test on the `SparcNet` model.
#
# ## Setup
#
# The `SleepEDF_demo/` folder must have the following structure:
# ```
# SleepEDF_demo/
#   SC-subjects.xls              # from https://physionet.org/files/sleep-edfx/1.0.0/SC-subjects.xls
#   sleepedf-cassette-pyhealth.csv  # auto-generated, then filtered to demo subjects only
#   sleep-cassette/
#     SC4001E0-PSG.edf
#     SC4001EC-Hypnogram.edf
#     SC4002E0-PSG.edf
#     SC4002EC-Hypnogram.edf
#     SC4011E0-PSG.edf
#     SC4011EH-Hypnogram.edf
# ```

# %%
import torch
from pathlib import Path
from pyhealth.datasets import SleepEDFDataset, get_dataloader
from pyhealth.models.sparcnet import SparcNet

# %% [markdown]
# ## Load SleepEDF Dataset and Set Task
#
# Load the SleepEDF cassette subset and apply the default `SleepStagingSleepEDF` task, which extracts 30-second EEG epochs labeled with sleep stages (W, N1, N2, N3, N4, R).

# %%
sleepedf_root = str(Path("../SleepEDF_demo").resolve())

dataset = SleepEDFDataset(root=sleepedf_root, subset="cassette")
task_dataset = dataset.set_task()

print(f"Total samples: {len(task_dataset)}")
sample = task_dataset[0]
print(f"Sample keys: {list(sample.keys())}")
print(f"Signal shape: {tuple(sample['signal'].shape)}")
print(f"Label classes: {sorted(set(int(task_dataset[i]['label']) for i in range(len(task_dataset))))}")
# Out:
# No config path provided, using default config
# Initializing sleepedf dataset from /Users/joshuachen/Projects/PyHealth/SleepEDF_demo (dev mode: False)
# Setting task SleepStaging for sleepedf base dataset...
# No cache_dir provided. Using default cache dir: /Users/joshuachen/Library/Caches/pyhealth/721549bc-455a-5885-9f13-ed4c6f3f4da0
# Found cached processed samples at /Users/joshuachen/Library/Caches/pyhealth/721549bc-455a-5885-9f13-ed4c6f3f4da0/tasks/SleepStaging_b6b1d496-535e-5188-b3a5-3e9c6731405a/samples_47c27255-9fc0-5271-bd99-638ffecdb1cc.ld, skipping processing.
# Total samples: 8281
# Sample keys: ['patient_id', 'night', 'patient_age', 'patient_sex', 'signal', 'label']
# Signal shape: (7, 3000)
# Label classes: [0, 1, 2, 3, 4, 5]

# %% [markdown]
# ## Initialize Model and Forward Pass
#
# Create a dataloader, initialize SparcNet from the dataset, and run a forward pass to verify the model produces loss and class probabilities.

# %%
loader = get_dataloader(task_dataset, batch_size=8, shuffle=False)
batch = next(iter(loader))

print("batch keys:", list(batch.keys()))
print("batch['signal'] shape:", tuple(batch["signal"].shape))
print("batch['label'] shape:", tuple(batch["label"].shape))

model = SparcNet(dataset=task_dataset)

with torch.no_grad():
    ret = model(**batch)

print("loss:", float(ret["loss"]))
print("y_prob shape:", tuple(ret["y_prob"].shape))
# Out:
# batch keys: ['patient_id', 'night', 'patient_age', 'patient_sex', 'signal', 'label']
# batch['signal'] shape: (8, 7, 3000)
# batch['label'] shape: (8,)
#
# === Input data statistics ===
# n_channels: 7
# length: 3000
# loss: 1.8694617748260498
# y_prob shape: (8, 6)

# %% [markdown]
# ## Create Train/Val/Test Data Loaders
#
# Create data loaders for training, validation, and evaluation.

# %%
train_loader = get_dataloader(task_dataset, batch_size=32, shuffle=True)
val_loader = get_dataloader(task_dataset, batch_size=8, shuffle=False)
test_loader = get_dataloader(task_dataset, batch_size=8, shuffle=False)

print("train batches:", len(train_loader))
print("val batches:", len(val_loader))
print("test batches:", len(test_loader))
# Out:
# train batches: 259
# val batches: 1036
# test batches: 1036

# %% [markdown]
# ## Train and Evaluate
#
# Train SparcNet for 1 epoch and evaluate on the test set.

# %%
from pyhealth.trainer import Trainer

trainer = Trainer(model=model, enable_logging=True)
trainer.train(
    train_dataloader=train_loader,
    val_dataloader=val_loader,
    epochs=1,
)

metrics = trainer.evaluate(test_loader)
print("Trainer eval metrics:", metrics)
# Out:
# SparcNet(
#   (encoder): Sequential(
#     (conv0): Conv1d(7, 8, kernel_size=(7,), stride=(2,), padding=(3,))
#     (norm0): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (elu0): ELU(alpha=1.0)
#     (pool0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(8, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(24, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(40, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(56, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition1): TransitionLayer(
#       (norm): BatchNorm1d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(72, 36, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock2): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(36, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(52, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(52, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(68, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(68, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(84, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition2): TransitionLayer(
#       (norm): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(100, 50, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock3): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(50, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(66, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(82, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(82, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(98, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(98, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition3): TransitionLayer(
#       (norm): BatchNorm1d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(114, 57, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock4): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(57, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(57, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(73, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(73, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(89, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(89, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(105, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(105, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition4): TransitionLayer(
#       (norm): BatchNorm1d(121, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(121, 60, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock5): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(60, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(76, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(76, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(92, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(92, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(108, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition5): TransitionLayer(
#       (norm): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(124, 62, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock6): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(62, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(62, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(78, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(94, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(94, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(110, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition6): TransitionLayer(
#       (norm): BatchNorm1d(126, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(126, 63, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock7): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(63, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(79, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(95, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(95, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(111, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(111, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition7): TransitionLayer(
#       (norm): BatchNorm1d(127, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(127, 63, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock8): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(63, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(79, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(95, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(95, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(111, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(111, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition8): TransitionLayer(
#       (norm): BatchNorm1d(127, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(127, 63, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (denseblock9): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm1d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(63, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(79, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm1d(95, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(95, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm1d(111, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu1): ELU(alpha=1.0)
#         (conv1): Conv1d(111, 256, kernel_size=(1,), stride=(1,))
#         (norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (elu2): ELU(alpha=1.0)
#         (conv2): Conv1d(256, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#     )
#     (transition9): TransitionLayer(
#       (norm): BatchNorm1d(127, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (elu): ELU(alpha=1.0)
#       (conv): Conv1d(127, 63, kernel_size=(1,), stride=(1,))
#       (pool): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (fc): Linear(in_features=63, out_features=6, bias=True)
# )
# Metrics: None
# Device: cpu
#
# Training:
# Batch size: 32
# Optimizer: <class 'torch.optim.adam.Adam'>
# Optimizer params: {'lr': 0.001}
# Weight decay: 0.0
# Max grad norm: None
# Val dataloader: <torch.utils.data.dataloader.DataLoader object at 0x38e110380>
# Monitor: None
# Monitor criterion: max
# Epochs: 1
# Patience: None
# Epoch 0 / 1:   0%|          | 0/259 [00:00<?, ?it/s]
# --- Train epoch-0, step-259 ---
# loss: 1.3366
# Evaluation: 100%|██████████| 1036/1036 [01:02<00:00, 16.62it/s]
# --- Eval epoch-0, step-259 ---
# accuracy: 0.6929
# f1_macro: 0.1364
# f1_micro: 0.6929
# loss: 0.9790
# Evaluation: 100%|██████████| 1036/1036 [01:03<00:00, 16.41it/s]
# Trainer eval metrics: {'accuracy': 0.6929114841202754, 'f1_macro': 0.13643388734336734, 'f1_micro': 0.6929114841202754, 'loss': 0.9789685920082234}
