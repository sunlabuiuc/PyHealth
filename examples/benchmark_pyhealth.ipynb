# %% [markdown]
# # benchmark load times using pandas vs. PyHealth

# %% [markdown]
# ## pandas

# %%
import pandas as pd
import time

path_to_massive_lab_events_table = "/srv/local/data/MIMIC-IV/2.0/hosp/labevents.csv"
path_to_massive_admissions_table = "/srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv"
path_to_massive_diagnoses_table = "/srv/local/data/MIMIC-IV/2.0/hosp/diagnoses_icd.csv"
path_to_massive_procedures_table = "/srv/local/data/MIMIC-IV/2.0/hosp/procedures_icd.csv"
path_to_massive_prescriptions_table = "/srv/local/data/MIMIC-IV/2.0/hosp/prescriptions.csv"
path_to_massive_patients_table = "/srv/local/data/MIMIC-IV/2.0/hosp/patients.csv"

# Time the file reading
start_time = time.perf_counter()
lab_df = pd.read_csv(path_to_massive_lab_events_table)
adm_df = pd.read_csv(path_to_massive_admissions_table)
diag_df = pd.read_csv(path_to_massive_diagnoses_table)
proc_df = pd.read_csv(path_to_massive_procedures_table)
presc_df = pd.read_csv(path_to_massive_prescriptions_table)
pat_df = pd.read_csv(path_to_massive_patients_table)
end_time = time.perf_counter()
read_time = end_time - start_time

print(f"Read time: {read_time:.2f} seconds")
print(f"Dataset shape: {lab_df.shape}")
# Out:
# /tmp/ipykernel_1511844/3475469019.py:17: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   presc_df = pd.read_csv(path_to_massive_prescriptions_table)
# Read time: 151.06 seconds
# Dataset shape: (124342638, 15)

# %% [markdown]
# ## pyhealth loading labevents

# %%
from pyhealth.datasets import MIMIC4Dataset
start_time = time.perf_counter()
root = "/srv/local/data/MIMIC-IV/2.0"
dataset = MIMIC4Dataset(ehr_root=root, ehr_tables=["diagnoses_icd", "procedures_icd", "prescriptions", "labevents"])
end_time = time.perf_counter()
read_time = end_time - start_time
print(f"Read time: {read_time:.2f} seconds")
# Out:
# Memory usage Starting MIMIC4Dataset init: 76030.8 MB
# Initializing MIMIC4EHRDataset with tables: ['diagnoses_icd', 'procedures_icd', 'prescriptions', 'labevents'] (dev mode: False)
# Using default EHR config: /home/johnwu3/projects/PyHealth_Branch_Testing/PyHealth/pyhealth/datasets/configs/mimic4_ehr.yaml
# Memory usage Before initializing mimic4_ehr: 76030.8 MB
# Initializing mimic4_ehr dataset from /srv/local/data/MIMIC-IV/2.0 (dev mode: False)
# Scanning table: diagnoses_icd from /srv/local/data/MIMIC-IV/2.0/hosp/diagnoses_icd.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/diagnoses_icd.csv
# Joining with table: /srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv
# Scanning table: procedures_icd from /srv/local/data/MIMIC-IV/2.0/hosp/procedures_icd.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/procedures_icd.csv
# Joining with table: /srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv
# Scanning table: prescriptions from /srv/local/data/MIMIC-IV/2.0/hosp/prescriptions.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/prescriptions.csv
# Scanning table: labevents from /srv/local/data/MIMIC-IV/2.0/hosp/labevents.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/labevents.csv
# Joining with table: /srv/local/data/MIMIC-IV/2.0/hosp/d_labitems.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/d_labitems.csv
# Scanning table: patients from /srv/local/data/MIMIC-IV/2.0/hosp/patients.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/patients.csv
# Scanning table: admissions from /srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv
# Scanning table: icustays from /srv/local/data/MIMIC-IV/2.0/icu/icustays.csv.gz
# Original path does not exist. Using alternative: /srv/local/data/MIMIC-IV/2.0/icu/icustays.csv
# Memory usage After initializing mimic4_ehr: 76030.7 MB
# Memory usage After EHR dataset initialization: 76030.7 MB
# Memory usage Before combining data: 76030.7 MB
# Combining data from ehr dataset
# Creating combined dataframe
# Memory usage After combining data: 76030.7 MB
# Memory usage Completed MIMIC4Dataset init: 76030.7 MB
# Read time: 0.03 seconds

# %% [markdown]
# ### When you actually do any processing: ~11.5 seconds

# %%
print(f"Dataset shape: {dataset.stats()}")
# Out:
# Collecting global event dataframe...
# Collected dataframe with shape: (28021083, 36)
# Dataset: mimic3
# Dev mode: False
# Number of patients: 46520
# Number of events: 28021083
# Dataset shape: None

# %% [markdown]
# # benchmarking task processing time
# ## pandas dataframe processing

# %%
import pandas as pd
import time
from datetime import datetime

def benchmark_mimic_processing(adm_df, diag_df, proc_df, presc_df, patients_df, n=1000):
    """
    Benchmark MIMIC-IV data processing for readmission prediction task.
    
    Args:
        adm_df: Admissions dataframe
        diag_df: Diagnoses dataframe  
        proc_df: Procedures dataframe
        presc_df: Prescriptions dataframe
        patients_df: Patients dataframe
        n: Number of patients to process (None = all patients)
    
    Returns:
        DataFrame with processed samples
    """
    print("Starting MIMIC-IV processing benchmark...")
    start_total = time.perf_counter()
    
    # Get patients to process
    if n is None:
        patients_to_process = patients_df['subject_id'].tolist()
        print(f"Processing all {len(patients_to_process)} patients...")
    else:
        patients_to_process = patients_df['subject_id'].head(n).tolist()
        print(f"Processing first {len(patients_to_process)} patients...")
    
    # Filter all dataframes to selected patients
    start_filter = time.perf_counter()
    
    adm_filtered = adm_df[adm_df['subject_id'].isin(patients_to_process)].copy()
    diag_filtered = diag_df[diag_df['subject_id'].isin(patients_to_process)].copy()
    proc_filtered = proc_df[proc_df['subject_id'].isin(patients_to_process)].copy()
    presc_filtered = presc_df[presc_df['subject_id'].isin(patients_to_process)].copy()
    patients_filtered = patients_df[patients_df['subject_id'].isin(patients_to_process)].copy()
    
    end_filter = time.perf_counter()
    print(f"Data filtering time: {end_filter - start_filter:.2f} seconds")
    
    # Convert datetime columns
    start_datetime = time.perf_counter()
    
    adm_filtered['admittime'] = pd.to_datetime(adm_filtered['admittime'])
    adm_filtered['dischtime'] = pd.to_datetime(adm_filtered['dischtime'])
    
    end_datetime = time.perf_counter()
    print(f"Datetime conversion time: {end_datetime - start_datetime:.2f} seconds")
    
    # Process each patient (mimicking the pyhealth task logic)
    start_processing = time.perf_counter()
    
    samples = []
    processed_patients = 0
    
    for subject_id in patients_to_process:
        # Get patient demographics
        patient_demo = patients_filtered[patients_filtered['subject_id'] == subject_id]
        if len(patient_demo) == 0:
            continue
            
        # Skip if under 18 (mimicking the age filter from pyhealth code)
        anchor_age = patient_demo.iloc[0]['anchor_age']
        if anchor_age < 18:
            continue
            
        # Get admissions for this patient, sorted by admit time
        patient_admissions = adm_filtered[
            adm_filtered['subject_id'] == subject_id
        ].sort_values('admittime')
        
        for i, (_, admission) in enumerate(patient_admissions.iterrows()):
            hadm_id = admission['hadm_id']
            admit_time = admission['admittime']
            discharge_time = admission['dischtime']
            
            if pd.isna(discharge_time):
                continue
                
            # Calculate admission duration (skip if <= 12 hours)
            duration_hours = (discharge_time - admit_time).total_seconds() / 3600
            if duration_hours <= 12:
                continue
            
            # Check for readmission within 30 days
            readmission = 0
            if i < len(patient_admissions) - 1:
                next_admission = patient_admissions.iloc[i + 1]
                next_admit_time = next_admission['admittime']
                time_diff_hours = (next_admit_time - discharge_time).total_seconds() / 3600
                
                if time_diff_hours <= 3:  # Skip if too close
                    continue
                    
                readmission = 1 if time_diff_hours < 30 * 24 else 0
            
            # Get events for this admission
            admission_diagnoses = diag_filtered[
                diag_filtered['hadm_id'] == hadm_id
            ]
            admission_procedures = proc_filtered[
                proc_filtered['hadm_id'] == hadm_id
            ]
            admission_prescriptions = presc_filtered[
                presc_filtered['hadm_id'] == hadm_id
            ]
            
            # Create condition codes (mimicking the pyhealth format)
            conditions = []
            if len(admission_diagnoses) > 0:
                conditions = [
                    f"{row['icd_version']}_{row['icd_code']}" 
                    for _, row in admission_diagnoses.iterrows()
                    if pd.notna(row['icd_code'])
                ]
            
            # Create procedure codes
            procedures = []
            if len(admission_procedures) > 0:
                procedures = [
                    f"{row['icd_version']}_{row['icd_code']}" 
                    for _, row in admission_procedures.iterrows()
                    if pd.notna(row['icd_code'])
                ]
            
            # Create drug codes
            drugs = []
            if len(admission_prescriptions) > 0:
                drugs = [
                    f"{row['drug']}" 
                    for _, row in admission_prescriptions.iterrows()
                    if pd.notna(row['drug'])
                ]
            
            # Skip if any category is empty (mimicking pyhealth logic)
            if len(conditions) == 0 or len(procedures) == 0 or len(drugs) == 0:
                continue
            
            samples.append({
                'patient_id': subject_id,
                'admission_id': hadm_id,
                'conditions': conditions,
                'procedures': procedures,
                'drugs': drugs,
                'readmission': readmission,
                'num_conditions': len(conditions),
                'num_procedures': len(procedures),
                'num_drugs': len(drugs)
            })
        
        processed_patients += 1
        if processed_patients % 100 == 0:
            print(f"Processed {processed_patients} patients...")
    
    end_processing = time.perf_counter()
    
    # Create results dataframe
    results_df = pd.DataFrame(samples)
    
    print("="*60)
    print("BENCHMARK RESULTS")
    print("="*60)
    print(f"Data filtering time: {end_filter - start_filter:.2f} seconds")
    print(f"Datetime conversion time: {end_datetime - start_datetime:.2f} seconds")
    print(f"Processing time: {end_processing - start_processing:.2f} seconds")
    print(f"Total time: {end_processing - start_total:.2f} seconds")
    print(f"Processed patients: {processed_patients}")
    print(f"Valid admissions: {len(results_df)}")
    
    if len(results_df) > 0:
        print(f"Readmission rate: {results_df['readmission'].mean():.3f}")
        print(f"Avg conditions per admission: {results_df['num_conditions'].mean():.1f}")
        print(f"Avg procedures per admission: {results_df['num_procedures'].mean():.1f}")
        print(f"Avg drugs per admission: {results_df['num_drugs'].mean():.1f}")
    
    return results_df


results = benchmark_mimic_processing(adm_df, diag_df, proc_df, presc_df, pat_df, n=None)
# Out:
# Starting MIMIC-IV processing benchmark...
# Processing all 315460 patients...
# Data filtering time: 4.05 seconds
# Datetime conversion time: 0.15 seconds
# Processed 100 patients...
# Processed 200 patients...
# Processed 300 patients...
# Processed 400 patients...
# Processed 500 patients...
# Processed 600 patients...
# Processed 700 patients...
# Processed 800 patients...
# Processed 900 patients...
# Processed 1000 patients...
# Processed 1100 patients...
# Processed 1200 patients...
# Processed 1300 patients...
# Processed 1400 patients...
# Processed 1500 patients...
# Processed 1600 patients...
# Processed 1700 patients...
# Processed 1800 patients...
# Processed 1900 patients...
# Processed 2000 patients...
# Processed 2100 patients...
# Processed 2200 patients...
# Processed 2300 patients...
# Processed 2400 patients...
# Processed 2500 patients...
# Processed 2600 patients...
# Processed 2700 patients...
# Processed 2800 patients...
# Processed 2900 patients...
# Processed 3000 patients...
# Processed 3100 patients...
# Processed 3200 patients...
# Processed 3300 patients...
# Processed 3400 patients...
# Processed 3500 patients...
# Processed 3600 patients...
# Processed 3700 patients...
# Processed 3800 patients...
# Processed 3900 patients...
# Processed 4000 patients...
# Processed 4100 patients...
# Processed 4200 patients...
# Processed 4300 patients...
# Processed 4400 patients...
# Processed 4500 patients...
# Processed 4600 patients...
# Processed 4700 patients...
# Processed 4800 patients...
# Processed 4900 patients...
# Processed 5000 patients...
# Processed 5100 patients...
# Processed 5200 patients...
# Processed 5300 patients...
# Processed 5400 patients...
# Processed 5500 patients...
# Processed 5600 patients...
# Processed 5700 patients...
# Processed 5800 patients...
# Processed 5900 patients...
# Processed 6000 patients...
# Processed 6100 patients...
# Processed 6200 patients...
# Processed 6300 patients...
# Processed 6400 patients...
# Processed 6500 patients...
# Processed 6600 patients...
# Processed 6700 patients...
# Processed 6800 patients...
# Processed 6900 patients...
# Processed 7000 patients...
# Processed 7100 patients...
# Processed 7200 patients...
# Processed 7300 patients...
# Processed 7400 patients...
# Processed 7500 patients...
# Processed 7600 patients...
# Processed 7700 patients...
# Processed 7800 patients...
# Processed 7900 patients...
# Processed 8000 patients...
# Processed 8100 patients...
# Processed 8200 patients...
# Processed 8300 patients...
# Processed 8400 patients...
# Processed 8500 patients...
# Processed 8600 patients...
# Processed 8700 patients...
# Processed 8800 patients...
# Processed 8900 patients...
# Processed 9000 patients...
# Processed 9100 patients...
# Processed 9200 patients...
# Processed 9300 patients...
# Processed 9400 patients...
# Processed 9500 patients...
# Processed 9600 patients...
# Processed 9700 patients...
# Processed 9800 patients...
# Processed 9900 patients...
# Processed 10000 patients...
# Processed 10100 patients...
# Processed 10200 patients...
# Processed 10300 patients...
# Processed 10400 patients...
# Processed 10500 patients...
# Processed 10600 patients...
# Processed 10700 patients...
# Processed 10800 patients...
# Processed 10900 patients...
# Processed 11000 patients...
# Processed 11100 patients...
# Processed 11200 patients...
# Processed 11300 patients...
# Processed 11400 patients...
# Processed 11500 patients...
# Processed 11600 patients...
# Processed 11700 patients...
# Processed 11800 patients...
# Processed 11900 patients...
# Processed 12000 patients...
# Processed 12100 patients...
# Processed 12200 patients...
# Processed 12300 patients...
# Processed 12400 patients...
# Processed 12500 patients...
# Processed 12600 patients...
# Processed 12700 patients...
# Processed 12800 patients...
# Processed 12900 patients...
# Processed 13000 patients...
# Processed 13100 patients...
# Processed 13200 patients...
# Processed 13300 patients...
# Processed 13400 patients...
# Processed 13500 patients...
# Processed 13600 patients...
# Processed 13700 patients...
# Processed 13800 patients...
# Processed 13900 patients...
# Processed 14000 patients...
# Processed 14100 patients...
# Processed 14200 patients...
# Processed 14300 patients...
# Processed 14400 patients...
# Processed 14500 patients...
# Processed 14600 patients...
# Processed 14700 patients...
# Processed 14800 patients...
# Processed 14900 patients...
# Processed 15000 patients...
# Processed 15100 patients...
# Processed 15200 patients...
# Processed 15300 patients...
# Processed 15400 patients...
# Processed 15500 patients...
# Processed 15600 patients...
# Processed 15700 patients...
# Processed 15800 patients...
# Processed 15900 patients...
# Processed 16000 patients...
# Processed 16100 patients...
# Processed 16200 patients...
# Processed 16300 patients...
# Processed 16400 patients...
# Processed 16500 patients...
# Processed 16600 patients...
# Processed 16700 patients...
# Processed 16800 patients...
# Processed 16900 patients...
# Processed 17000 patients...
# Processed 17100 patients...
# Processed 17200 patients...
# Processed 17300 patients...
# Processed 17400 patients...
# Processed 17500 patients...
# Processed 17600 patients...
# Processed 17700 patients...
# Processed 17800 patients...
# Processed 17900 patients...
# Processed 18000 patients...
# Processed 18100 patients...
# Processed 18200 patients...
# Processed 18300 patients...
# Processed 18400 patients...
# Processed 18500 patients...
# Processed 18600 patients...
# Processed 18700 patients...
# Processed 18800 patients...
# Processed 18900 patients...
# Processed 19000 patients...
# Processed 19100 patients...
# Processed 19200 patients...
# Processed 19300 patients...
# Processed 19400 patients...
# Processed 19500 patients...
# Processed 19600 patients...
# Processed 19700 patients...
# Processed 19800 patients...
# Processed 19900 patients...
# Processed 20000 patients...
# Processed 20100 patients...
# Processed 20200 patients...
# Processed 20300 patients...
# Processed 20400 patients...
# Processed 20500 patients...
# Processed 20600 patients...
# Processed 20700 patients...
# Processed 20800 patients...
# Processed 20900 patients...
# Processed 21000 patients...
# Processed 21100 patients...
# Processed 21200 patients...
# Processed 21300 patients...
# Processed 21400 patients...
# Processed 21500 patients...
# Processed 21600 patients...
# Processed 21700 patients...
# Processed 21800 patients...
# Processed 21900 patients...
# Processed 22000 patients...
# Processed 22100 patients...
# Processed 22200 patients...
# Processed 22300 patients...
# Processed 22400 patients...
# Processed 22500 patients...
# Processed 22600 patients...
# Processed 22700 patients...
# Processed 22800 patients...
# Processed 22900 patients...
# Processed 23000 patients...
# Processed 23100 patients...
# Processed 23200 patients...
# Processed 23300 patients...
# Processed 23400 patients...
# Processed 23500 patients...
# Processed 23600 patients...
# Processed 23700 patients...
# Processed 23800 patients...
# Processed 23900 patients...
# Processed 24000 patients...
# Processed 24100 patients...
# Processed 24200 patients...
# Processed 24300 patients...
# Processed 24400 patients...
# Processed 24500 patients...
# Processed 24600 patients...
# Processed 24700 patients...
# Processed 24800 patients...
# Processed 24900 patients...
# Processed 25000 patients...
# Processed 25100 patients...
# Processed 25200 patients...
# Processed 25300 patients...
# Processed 25400 patients...
# Processed 25500 patients...
# Processed 25600 patients...
# Processed 25700 patients...
# Processed 25800 patients...
# Processed 25900 patients...
# Processed 26000 patients...
# Processed 26100 patients...
# Processed 26200 patients...
# Processed 26300 patients...
# Processed 26400 patients...
# Processed 26500 patients...
# Processed 26600 patients...
# Processed 26700 patients...
# Processed 26800 patients...
# Processed 26900 patients...
# Processed 27000 patients...
# Processed 27100 patients...
# Processed 27200 patients...
# Processed 27300 patients...
# Processed 27400 patients...
# Processed 27500 patients...
# Processed 27600 patients...
# Processed 27700 patients...
# Processed 27800 patients...
# Processed 27900 patients...
# Processed 28000 patients...
# Processed 28100 patients...
# Processed 28200 patients...
# Processed 28300 patients...
# Processed 28400 patients...
# Processed 28500 patients...
# Processed 28600 patients...
# Processed 28700 patients...
# Processed 28800 patients...
# Processed 28900 patients...
# Processed 29000 patients...
# Processed 29100 patients...
# Processed 29200 patients...
# Processed 29300 patients...
# Processed 29400 patients...
# Processed 29500 patients...
# Processed 29600 patients...
# Processed 29700 patients...
# Processed 29800 patients...
# Processed 29900 patients...
# Processed 30000 patients...
# Processed 30100 patients...
# Processed 30200 patients...
# Processed 30300 patients...
# Processed 30400 patients...
# Processed 30500 patients...
# Processed 30600 patients...
# Processed 30700 patients...
# Processed 30800 patients...
# Processed 30900 patients...
# Processed 31000 patients...
# Processed 31100 patients...
# Processed 31200 patients...
# Processed 31300 patients...
# Processed 31400 patients...
# Processed 31500 patients...
# Processed 31600 patients...
# Processed 31700 patients...
# Processed 31800 patients...
# Processed 31900 patients...
# Processed 32000 patients...
# Processed 32100 patients...
# Processed 32200 patients...
# Processed 32300 patients...
# Processed 32400 patients...
# Processed 32500 patients...
# Processed 32600 patients...
# Processed 32700 patients...
# Processed 32800 patients...
# Processed 32900 patients...
# Processed 33000 patients...
# Processed 33100 patients...
# Processed 33200 patients...
# Processed 33300 patients...
# Processed 33400 patients...
# Processed 33500 patients...
# Processed 33600 patients...
# Processed 33700 patients...
# Processed 33800 patients...
# Processed 33900 patients...
# Processed 34000 patients...
# Processed 34100 patients...
# Processed 34200 patients...
# Processed 34300 patients...
# Processed 34400 patients...
# Processed 34500 patients...
# Processed 34600 patients...
# Processed 34700 patients...
# Processed 34800 patients...
# Processed 34900 patients...
# Processed 35000 patients...
# Processed 35100 patients...
# Processed 35200 patients...
# Processed 35300 patients...
# Processed 35400 patients...
# Processed 35500 patients...
# Processed 35600 patients...
# Processed 35700 patients...
# Processed 35800 patients...
# Processed 35900 patients...
# Processed 36000 patients...
# Processed 36100 patients...
# Processed 36200 patients...
# Processed 36300 patients...
# Processed 36400 patients...
# Processed 36500 patients...
# Processed 36600 patients...
# Processed 36700 patients...
# Processed 36800 patients...
# Processed 36900 patients...
# Processed 37000 patients...
# Processed 37100 patients...
# Processed 37200 patients...
# Processed 37300 patients...
# Processed 37400 patients...
# Processed 37500 patients...
# Processed 37600 patients...
# Processed 37700 patients...
# Processed 37800 patients...
# Processed 37900 patients...
# Processed 38000 patients...
# Processed 38100 patients...
# Processed 38200 patients...
# Processed 38300 patients...
# Processed 38400 patients...
# Processed 38500 patients...
# Processed 38600 patients...
# Processed 38700 patients...
# Processed 38800 patients...
# Processed 38900 patients...
# Processed 39000 patients...
# Processed 39100 patients...
# Processed 39200 patients...
# Processed 39300 patients...
# Processed 39400 patients...
# Processed 39500 patients...
# Processed 39600 patients...
# Processed 39700 patients...
# Processed 39800 patients...
# Processed 39900 patients...
# Processed 40000 patients...
# Processed 40100 patients...
# Processed 40200 patients...
# Processed 40300 patients...
# Processed 40400 patients...
# Processed 40500 patients...
# Processed 40600 patients...
# Processed 40700 patients...
# Processed 40800 patients...
# Processed 40900 patients...
# Processed 41000 patients...
# Processed 41100 patients...
# Processed 41200 patients...
# Processed 41300 patients...
# Processed 41400 patients...
# Processed 41500 patients...
# Processed 41600 patients...
# Processed 41700 patients...
# Processed 41800 patients...
# Processed 41900 patients...
# Processed 42000 patients...
# Processed 42100 patients...
# Processed 42200 patients...
# Processed 42300 patients...
# Processed 42400 patients...
# Processed 42500 patients...
# Processed 42600 patients...
# Processed 42700 patients...
# Processed 42800 patients...
# Processed 42900 patients...
# Processed 43000 patients...
# Processed 43100 patients...
# Processed 43200 patients...
# Processed 43300 patients...
# Processed 43400 patients...
# Processed 43500 patients...
# Processed 43600 patients...
# Processed 43700 patients...
# Processed 43800 patients...
# Processed 43900 patients...
# Processed 44000 patients...
# Processed 44100 patients...
# Processed 44200 patients...
# Processed 44300 patients...
# Processed 44400 patients...
# Processed 44500 patients...
# Processed 44600 patients...
# Processed 44700 patients...
# Processed 44800 patients...
# Processed 44900 patients...
# Processed 45000 patients...
# Processed 45100 patients...
# Processed 45200 patients...
# Processed 45300 patients...
# Processed 45400 patients...
# Processed 45500 patients...
# Processed 45600 patients...
# Processed 45700 patients...
# Processed 45800 patients...
# Processed 45900 patients...
# Processed 46000 patients...
# Processed 46100 patients...
# Processed 46200 patients...
# Processed 46300 patients...
# Processed 46400 patients...
# Processed 46500 patients...
# Processed 46600 patients...
# Processed 46700 patients...
# Processed 46800 patients...
# Processed 46900 patients...
# Processed 47000 patients...
# Processed 47100 patients...
# Processed 47200 patients...
# Processed 47300 patients...
# Processed 47400 patients...
# Processed 47500 patients...
# Processed 47600 patients...
# Processed 47700 patients...
# Processed 47800 patients...
# Processed 47900 patients...
# Processed 48000 patients...
# Processed 48100 patients...
# Processed 48200 patients...
# Processed 48300 patients...
# Processed 48400 patients...
# Processed 48500 patients...
# Processed 48600 patients...
# Processed 48700 patients...
# Processed 48800 patients...
# Processed 48900 patients...
# Processed 49000 patients...
# Processed 49100 patients...
# Processed 49200 patients...
# Processed 49300 patients...
# Processed 49400 patients...
# Processed 49500 patients...
# Processed 49600 patients...
# Processed 49700 patients...
# Processed 49800 patients...
# Processed 49900 patients...
# Processed 50000 patients...
# Processed 50100 patients...
# Processed 50200 patients...
# Processed 50300 patients...
# Processed 50400 patients...
# Processed 50500 patients...
# Processed 50600 patients...
# Processed 50700 patients...
# Processed 50800 patients...
# Processed 50900 patients...
# Processed 51000 patients...
# Processed 51100 patients...
# Processed 51200 patients...
# Processed 51300 patients...
# Processed 51400 patients...
# Processed 51500 patients...
# Processed 51600 patients...
# Processed 51700 patients...
# Processed 51800 patients...
# Processed 51900 patients...
# Processed 52000 patients...
# Processed 52100 patients...
# Processed 52200 patients...
# Processed 52300 patients...
# Processed 52400 patients...
# Processed 52500 patients...
# Processed 52600 patients...
# Processed 52700 patients...
# Processed 52800 patients...
# Processed 52900 patients...
# Processed 53000 patients...
# Processed 53100 patients...
# Processed 53200 patients...
# Processed 53300 patients...
# Processed 53400 patients...
# Processed 53500 patients...
# Processed 53600 patients...
# Processed 53700 patients...
# Processed 53800 patients...
# Processed 53900 patients...
# Processed 54000 patients...
# Processed 54100 patients...
# Processed 54200 patients...
# Processed 54300 patients...
# Processed 54400 patients...
# Processed 54500 patients...
# Processed 54600 patients...
# Processed 54700 patients...
# Processed 54800 patients...
# Processed 54900 patients...
# Processed 55000 patients...
# Processed 55100 patients...
# Processed 55200 patients...
# Processed 55300 patients...
# Processed 55400 patients...
# Processed 55500 patients...
# Processed 55600 patients...
# Processed 55700 patients...
# Processed 55800 patients...
# Processed 55900 patients...
# Processed 56000 patients...
# Processed 56100 patients...
# Processed 56200 patients...
# Processed 56300 patients...
# Processed 56400 patients...
# Processed 56500 patients...
# Processed 56600 patients...
# Processed 56700 patients...
# Processed 56800 patients...
# Processed 56900 patients...
# Processed 57000 patients...
# Processed 57100 patients...
# Processed 57200 patients...
# Processed 57300 patients...
# Processed 57400 patients...
# Processed 57500 patients...
# Processed 57600 patients...
# Processed 57700 patients...
# Processed 57800 patients...
# Processed 57900 patients...
# Processed 58000 patients...
# Processed 58100 patients...
# Processed 58200 patients...
# Processed 58300 patients...
# Processed 58400 patients...
# Processed 58500 patients...
# Processed 58600 patients...
# Processed 58700 patients...
# Processed 58800 patients...
# Processed 58900 patients...
# Processed 59000 patients...
# Processed 59100 patients...
# Processed 59200 patients...
# Processed 59300 patients...
# Processed 59400 patients...
# Processed 59500 patients...
# Processed 59600 patients...
# Processed 59700 patients...
# Processed 59800 patients...
# Processed 59900 patients...
# Processed 60000 patients...
# Processed 60100 patients...
# Processed 60200 patients...
# Processed 60300 patients...
# Processed 60400 patients...
# Processed 60500 patients...
# Processed 60600 patients...
# Processed 60700 patients...
# Processed 60800 patients...
# Processed 60900 patients...
# Processed 61000 patients...
# Processed 61100 patients...
# Processed 61200 patients...
# Processed 61300 patients...
# Processed 61400 patients...
# Processed 61500 patients...
# Processed 61600 patients...
# Processed 61700 patients...
# Processed 61800 patients...
# Processed 61900 patients...
# Processed 62000 patients...
# Processed 62100 patients...
# Processed 62200 patients...
# Processed 62300 patients...
# Processed 62400 patients...
# Processed 62500 patients...
# Processed 62600 patients...
# Processed 62700 patients...
# Processed 62800 patients...
# Processed 62900 patients...
# Processed 63000 patients...
# Processed 63100 patients...
# Processed 63200 patients...
# Processed 63300 patients...
# Processed 63400 patients...
# Processed 63500 patients...
# Processed 63600 patients...
# Processed 63700 patients...
# Processed 63800 patients...
# Processed 63900 patients...
# Processed 64000 patients...
# Processed 64100 patients...
# Processed 64200 patients...
# Processed 64300 patients...
# Processed 64400 patients...
# Processed 64500 patients...
# Processed 64600 patients...
# Processed 64700 patients...
# Processed 64800 patients...
# Processed 64900 patients...
# Processed 65000 patients...
# Processed 65100 patients...
# Processed 65200 patients...
# Processed 65300 patients...
# Processed 65400 patients...
# Processed 65500 patients...
# Processed 65600 patients...
# Processed 65700 patients...
# Processed 65800 patients...
# Processed 65900 patients...
# Processed 66000 patients...
# Processed 66100 patients...
# Processed 66200 patients...
# Processed 66300 patients...
# Processed 66400 patients...
# Processed 66500 patients...
# Processed 66600 patients...
# Processed 66700 patients...
# Processed 66800 patients...
# Processed 66900 patients...
# Processed 67000 patients...
# Processed 67100 patients...
# Processed 67200 patients...
# Processed 67300 patients...
# Processed 67400 patients...
# Processed 67500 patients...
# Processed 67600 patients...
# Processed 67700 patients...
# Processed 67800 patients...
# Processed 67900 patients...
# Processed 68000 patients...
# Processed 68100 patients...
# Processed 68200 patients...
# Processed 68300 patients...
# Processed 68400 patients...
# Processed 68500 patients...
# Processed 68600 patients...
# Processed 68700 patients...
# Processed 68800 patients...
# Processed 68900 patients...
# Processed 69000 patients...
# Processed 69100 patients...
# Processed 69200 patients...
# Processed 69300 patients...
# Processed 69400 patients...
# Processed 69500 patients...
# Processed 69600 patients...
# Processed 69700 patients...
# Processed 69800 patients...
# Processed 69900 patients...
# Processed 70000 patients...
# Processed 70100 patients...
# Processed 70200 patients...
# Processed 70300 patients...
# Processed 70400 patients...
# Processed 70500 patients...
# Processed 70600 patients...
# Processed 70700 patients...
# Processed 70800 patients...
# Processed 70900 patients...
# Processed 71000 patients...
# Processed 71100 patients...
# Processed 71200 patients...
# Processed 71300 patients...
# Processed 71400 patients...
# Processed 71500 patients...
# Processed 71600 patients...
# Processed 71700 patients...
# Processed 71800 patients...
# Processed 71900 patients...
# Processed 72000 patients...
# Processed 72100 patients...
# Processed 72200 patients...
# Processed 72300 patients...
# Processed 72400 patients...
# Processed 72500 patients...
# Processed 72600 patients...
# Processed 72700 patients...
# Processed 72800 patients...
# Processed 72900 patients...
# Processed 73000 patients...
# Processed 73100 patients...
# Processed 73200 patients...
# Processed 73300 patients...
# Processed 73400 patients...
# Processed 73500 patients...
# Processed 73600 patients...
# Processed 73700 patients...
# Processed 73800 patients...
# Processed 73900 patients...
# Processed 74000 patients...
# Processed 74100 patients...
# Processed 74200 patients...
# Processed 74300 patients...
# Processed 74400 patients...
# Processed 74500 patients...
# Processed 74600 patients...
# Processed 74700 patients...
# Processed 74800 patients...
# Processed 74900 patients...
# Processed 75000 patients...
# Processed 75100 patients...
# Processed 75200 patients...
# Processed 75300 patients...
# Processed 75400 patients...
# Processed 75500 patients...
# Processed 75600 patients...
# Processed 75700 patients...
# Processed 75800 patients...
# Processed 75900 patients...
# Processed 76000 patients...
# Processed 76100 patients...
# Processed 76200 patients...
# Processed 76300 patients...
# Processed 76400 patients...
# Processed 76500 patients...
# Processed 76600 patients...
# Processed 76700 patients...
# Processed 76800 patients...
# Processed 76900 patients...
# Processed 77000 patients...
# Processed 77100 patients...
# Processed 77200 patients...
# Processed 77300 patients...
# Processed 77400 patients...
# Processed 77500 patients...
# Processed 77600 patients...
# Processed 77700 patients...
# Processed 77800 patients...
# Processed 77900 patients...
# Processed 78000 patients...
# Processed 78100 patients...
# Processed 78200 patients...
# Processed 78300 patients...
# Processed 78400 patients...
# Processed 78500 patients...
# Processed 78600 patients...
# Processed 78700 patients...
# Processed 78800 patients...
# Processed 78900 patients...
# Processed 79000 patients...
# Processed 79100 patients...
# Processed 79200 patients...
# Processed 79300 patients...
# Processed 79400 patients...
# Processed 79500 patients...
# Processed 79600 patients...
# Processed 79700 patients...
# Processed 79800 patients...
# Processed 79900 patients...
# Processed 80000 patients...
# Processed 80100 patients...
# Processed 80200 patients...
# Processed 80300 patients...
# Processed 80400 patients...
# Processed 80500 patients...
# Processed 80600 patients...
# Processed 80700 patients...
# Processed 80800 patients...
# Processed 80900 patients...
# Processed 81000 patients...
# Processed 81100 patients...
# Processed 81200 patients...
# Processed 81300 patients...
# Processed 81400 patients...
# Processed 81500 patients...
# Processed 81600 patients...
# Processed 81700 patients...
# Processed 81800 patients...
# Processed 81900 patients...
# Processed 82000 patients...
# Processed 82100 patients...
# Processed 82200 patients...
# Processed 82300 patients...
# Processed 82400 patients...
# Processed 82500 patients...
# Processed 82600 patients...
# Processed 82700 patients...
# Processed 82800 patients...
# Processed 82900 patients...
# Processed 83000 patients...
# Processed 83100 patients...
# Processed 83200 patients...
# Processed 83300 patients...
# Processed 83400 patients...
# Processed 83500 patients...
# Processed 83600 patients...
# Processed 83700 patients...
# Processed 83800 patients...
# Processed 83900 patients...
# Processed 84000 patients...
# Processed 84100 patients...
# Processed 84200 patients...
# Processed 84300 patients...
# Processed 84400 patients...
# Processed 84500 patients...
# Processed 84600 patients...
# Processed 84700 patients...
# Processed 84800 patients...
# Processed 84900 patients...
# Processed 85000 patients...
# Processed 85100 patients...
# Processed 85200 patients...
# Processed 85300 patients...
# Processed 85400 patients...
# Processed 85500 patients...
# Processed 85600 patients...
# Processed 85700 patients...
# Processed 85800 patients...
# Processed 85900 patients...
# Processed 86000 patients...
# Processed 86100 patients...
# Processed 86200 patients...
# Processed 86300 patients...
# Processed 86400 patients...
# Processed 86500 patients...
# Processed 86600 patients...
# Processed 86700 patients...
# Processed 86800 patients...
# Processed 86900 patients...
# Processed 87000 patients...
# Processed 87100 patients...
# Processed 87200 patients...
# Processed 87300 patients...
# Processed 87400 patients...
# Processed 87500 patients...
# Processed 87600 patients...
# Processed 87700 patients...
# Processed 87800 patients...
# Processed 87900 patients...
# Processed 88000 patients...
# Processed 88100 patients...
# Processed 88200 patients...
# Processed 88300 patients...
# Processed 88400 patients...
# Processed 88500 patients...
# Processed 88600 patients...
# Processed 88700 patients...
# Processed 88800 patients...
# Processed 88900 patients...
# Processed 89000 patients...
# Processed 89100 patients...
# Processed 89200 patients...
# Processed 89300 patients...
# Processed 89400 patients...
# Processed 89500 patients...
# Processed 89600 patients...
# Processed 89700 patients...
# Processed 89800 patients...
# Processed 89900 patients...
# Processed 90000 patients...
# Processed 90100 patients...
# Processed 90200 patients...
# Processed 90300 patients...
# Processed 90400 patients...
# Processed 90500 patients...
# Processed 90600 patients...
# Processed 90700 patients...
# Processed 90800 patients...
# Processed 90900 patients...
# Processed 91000 patients...
# Processed 91100 patients...
# Processed 91200 patients...
# Processed 91300 patients...
# Processed 91400 patients...
# Processed 91500 patients...
# Processed 91600 patients...
# Processed 91700 patients...
# Processed 91800 patients...
# Processed 91900 patients...
# Processed 92000 patients...
# Processed 92100 patients...
# Processed 92200 patients...
# Processed 92300 patients...
# Processed 92400 patients...
# Processed 92500 patients...
# Processed 92600 patients...
# Processed 92700 patients...
# Processed 92800 patients...
# Processed 92900 patients...
# Processed 93000 patients...
# Processed 93100 patients...
# Processed 93200 patients...
# Processed 93300 patients...
# Processed 93400 patients...
# Processed 93500 patients...
# Processed 93600 patients...
# Processed 93700 patients...
# Processed 93800 patients...
# Processed 93900 patients...
# Processed 94000 patients...
# Processed 94100 patients...
# Processed 94200 patients...
# Processed 94300 patients...
# Processed 94400 patients...
# Processed 94500 patients...
# Processed 94600 patients...
# Processed 94700 patients...
# Processed 94800 patients...
# Processed 94900 patients...
# Processed 95000 patients...
# Processed 95100 patients...
# Processed 95200 patients...
# Processed 95300 patients...
# Processed 95400 patients...
# Processed 95500 patients...
# Processed 95600 patients...
# Processed 95700 patients...
# Processed 95800 patients...
# Processed 95900 patients...
# Processed 96000 patients...
# Processed 96100 patients...
# Processed 96200 patients...
# Processed 96300 patients...
# Processed 96400 patients...
# Processed 96500 patients...
# Processed 96600 patients...
# Processed 96700 patients...
# Processed 96800 patients...
# Processed 96900 patients...
# Processed 97000 patients...
# Processed 97100 patients...
# Processed 97200 patients...
# Processed 97300 patients...
# Processed 97400 patients...
# Processed 97500 patients...
# Processed 97600 patients...
# Processed 97700 patients...
# Processed 97800 patients...
# Processed 97900 patients...
# Processed 98000 patients...
# Processed 98100 patients...
# Processed 98200 patients...
# Processed 98300 patients...
# Processed 98400 patients...
# Processed 98500 patients...
# Processed 98600 patients...
# Processed 98700 patients...
# Processed 98800 patients...
# Processed 98900 patients...
# Processed 99000 patients...
# Processed 99100 patients...
# Processed 99200 patients...
# Processed 99300 patients...
# Processed 99400 patients...
# Processed 99500 patients...
# Processed 99600 patients...
# Processed 99700 patients...
# Processed 99800 patients...
# Processed 99900 patients...
# Processed 100000 patients...
# Processed 100100 patients...
# Processed 100200 patients...
# Processed 100300 patients...
# Processed 100400 patients...
# Processed 100500 patients...
# Processed 100600 patients...
# Processed 100700 patients...
# Processed 100800 patients...
# Processed 100900 patients...
# Processed 101000 patients...
# Processed 101100 patients...
# Processed 101200 patients...
# Processed 101300 patients...
# Processed 101400 patients...
# Processed 101500 patients...
# Processed 101600 patients...
# Processed 101700 patients...
# Processed 101800 patients...
# Processed 101900 patients...
# Processed 102000 patients...
# Processed 102100 patients...
# Processed 102200 patients...
# Processed 102300 patients...
# Processed 102400 patients...
# Processed 102500 patients...
# Processed 102600 patients...
# Processed 102700 patients...
# Processed 102800 patients...
# Processed 102900 patients...
# Processed 103000 patients...
# Processed 103100 patients...
# Processed 103200 patients...
# Processed 103300 patients...
# Processed 103400 patients...
# Processed 103500 patients...
# Processed 103600 patients...
# Processed 103700 patients...
# Processed 103800 patients...
# Processed 103900 patients...
# Processed 104000 patients...
# Processed 104100 patients...
# Processed 104200 patients...
# Processed 104300 patients...
# Processed 104400 patients...
# Processed 104500 patients...
# Processed 104600 patients...
# Processed 104700 patients...
# Processed 104800 patients...
# Processed 104900 patients...
# Processed 105000 patients...
# Processed 105100 patients...
# Processed 105200 patients...
# Processed 105300 patients...
# Processed 105400 patients...
# Processed 105500 patients...
# Processed 105600 patients...
# Processed 105700 patients...
# Processed 105800 patients...
# Processed 105900 patients...
# Processed 106000 patients...
# Processed 106100 patients...
# Processed 106200 patients...
# Processed 106300 patients...
# Processed 106400 patients...
# Processed 106500 patients...
# Processed 106600 patients...
# Processed 106700 patients...
# Processed 106800 patients...
# Processed 106900 patients...
# Processed 107000 patients...
# Processed 107100 patients...
# Processed 107200 patients...
# Processed 107300 patients...
# Processed 107400 patients...
# Processed 107500 patients...
# Processed 107600 patients...
# Processed 107700 patients...
# Processed 107800 patients...
# Processed 107900 patients...
# Processed 108000 patients...
# Processed 108100 patients...
# Processed 108200 patients...
# Processed 108300 patients...
# Processed 108400 patients...
# Processed 108500 patients...
# Processed 108600 patients...
# Processed 108700 patients...
# Processed 108800 patients...
# Processed 108900 patients...
# Processed 109000 patients...
# Processed 109100 patients...
# Processed 109200 patients...
# Processed 109300 patients...
# Processed 109400 patients...
# Processed 109500 patients...
# Processed 109600 patients...
# Processed 109700 patients...
# Processed 109800 patients...
# Processed 109900 patients...
# Processed 110000 patients...
# Processed 110100 patients...
# Processed 110200 patients...
# Processed 110300 patients...
# Processed 110400 patients...
# Processed 110500 patients...
# Processed 110600 patients...
# Processed 110700 patients...
# Processed 110800 patients...
# Processed 110900 patients...
# Processed 111000 patients...
# Processed 111100 patients...
# Processed 111200 patients...
# Processed 111300 patients...
# Processed 111400 patients...
# Processed 111500 patients...
# Processed 111600 patients...
# Processed 111700 patients...
# Processed 111800 patients...
# Processed 111900 patients...
# Processed 112000 patients...
# Processed 112100 patients...
# Processed 112200 patients...
# Processed 112300 patients...
# Processed 112400 patients...
# Processed 112500 patients...
# Processed 112600 patients...
# Processed 112700 patients...
# Processed 112800 patients...
# Processed 112900 patients...
# Processed 113000 patients...
# Processed 113100 patients...
# Processed 113200 patients...
# Processed 113300 patients...
# Processed 113400 patients...
# Processed 113500 patients...
# Processed 113600 patients...
# Processed 113700 patients...
# Processed 113800 patients...
# Processed 113900 patients...
# Processed 114000 patients...
# Processed 114100 patients...
# Processed 114200 patients...
# Processed 114300 patients...
# Processed 114400 patients...
# Processed 114500 patients...
# Processed 114600 patients...
# Processed 114700 patients...
# Processed 114800 patients...
# Processed 114900 patients...
# Processed 115000 patients...
# Processed 115100 patients...
# Processed 115200 patients...
# Processed 115300 patients...
# Processed 115400 patients...
# Processed 115500 patients...
# Processed 115600 patients...
# Processed 115700 patients...
# Processed 115800 patients...
# Processed 115900 patients...
# Processed 116000 patients...
# Processed 116100 patients...
# Processed 116200 patients...
# Processed 116300 patients...
# Processed 116400 patients...
# Processed 116500 patients...
# Processed 116600 patients...
# Processed 116700 patients...
# Processed 116800 patients...
# Processed 116900 patients...
# Processed 117000 patients...
# Processed 117100 patients...
# Processed 117200 patients...
# Processed 117300 patients...
# Processed 117400 patients...
# Processed 117500 patients...
# Processed 117600 patients...
# Processed 117700 patients...
# Processed 117800 patients...
# Processed 117900 patients...
# Processed 118000 patients...
# Processed 118100 patients...
# Processed 118200 patients...
# Processed 118300 patients...
# Processed 118400 patients...
# Processed 118500 patients...
# Processed 118600 patients...
# Processed 118700 patients...
# Processed 118800 patients...
# Processed 118900 patients...
# Processed 119000 patients...
# Processed 119100 patients...
# Processed 119200 patients...
# Processed 119300 patients...
# Processed 119400 patients...
# Processed 119500 patients...
# Processed 119600 patients...
# Processed 119700 patients...
# Processed 119800 patients...
# Processed 119900 patients...
# Processed 120000 patients...
# Processed 120100 patients...
# Processed 120200 patients...
# Processed 120300 patients...
# Processed 120400 patients...
# Processed 120500 patients...
# Processed 120600 patients...
# Processed 120700 patients...
# Processed 120800 patients...
# Processed 120900 patients...
# Processed 121000 patients...
# Processed 121100 patients...
# Processed 121200 patients...
# Processed 121300 patients...
# Processed 121400 patients...
# Processed 121500 patients...
# Processed 121600 patients...
# Processed 121700 patients...
# Processed 121800 patients...
# Processed 121900 patients...
# Processed 122000 patients...
# Processed 122100 patients...
# Processed 122200 patients...
# Processed 122300 patients...
# Processed 122400 patients...
# Processed 122500 patients...
# Processed 122600 patients...
# Processed 122700 patients...
# Processed 122800 patients...
# Processed 122900 patients...
# Processed 123000 patients...
# Processed 123100 patients...
# Processed 123200 patients...
# Processed 123300 patients...
# Processed 123400 patients...
# Processed 123500 patients...
# Processed 123600 patients...
# Processed 123700 patients...
# Processed 123800 patients...
# Processed 123900 patients...
# Processed 124000 patients...
# Processed 124100 patients...
# Processed 124200 patients...
# Processed 124300 patients...
# Processed 124400 patients...
# Processed 124500 patients...
# Processed 124600 patients...
# Processed 124700 patients...
# Processed 124800 patients...
# Processed 124900 patients...
# Processed 125000 patients...
# Processed 125100 patients...
# Processed 125200 patients...
# Processed 125300 patients...
# Processed 125400 patients...
# Processed 125500 patients...
# Processed 125600 patients...
# Processed 125700 patients...
# Processed 125800 patients...
# Processed 125900 patients...
# Processed 126000 patients...
# Processed 126100 patients...
# Processed 126200 patients...
# Processed 126300 patients...
# Processed 126400 patients...
# Processed 126500 patients...
# Processed 126600 patients...
# Processed 126700 patients...
# Processed 126800 patients...
# Processed 126900 patients...
# Processed 127000 patients...
# Processed 127100 patients...
# Processed 127200 patients...
# Processed 127300 patients...
# Processed 127400 patients...
# Processed 127500 patients...
# Processed 127600 patients...
# Processed 127700 patients...
# Processed 127800 patients...
# Processed 127900 patients...
# Processed 128000 patients...
# Processed 128100 patients...
# Processed 128200 patients...
# Processed 128300 patients...
# Processed 128400 patients...
# Processed 128500 patients...
# Processed 128600 patients...
# Processed 128700 patients...
# Processed 128800 patients...
# Processed 128900 patients...
# Processed 129000 patients...
# Processed 129100 patients...
# Processed 129200 patients...
# Processed 129300 patients...
# Processed 129400 patients...
# Processed 129500 patients...
# Processed 129600 patients...
# Processed 129700 patients...
# Processed 129800 patients...
# Processed 129900 patients...
# Processed 130000 patients...
# Processed 130100 patients...
# Processed 130200 patients...
# Processed 130300 patients...
# Processed 130400 patients...
# Processed 130500 patients...
# Processed 130600 patients...
# Processed 130700 patients...
# Processed 130800 patients...
# Processed 130900 patients...
# Processed 131000 patients...
# Processed 131100 patients...
# Processed 131200 patients...
# Processed 131300 patients...
# Processed 131400 patients...
# Processed 131500 patients...
# Processed 131600 patients...
# Processed 131700 patients...
# Processed 131800 patients...
# Processed 131900 patients...
# Processed 132000 patients...
# Processed 132100 patients...
# Processed 132200 patients...
# Processed 132300 patients...
# Processed 132400 patients...
# Processed 132500 patients...
# Processed 132600 patients...
# Processed 132700 patients...
# Processed 132800 patients...
# Processed 132900 patients...
# Processed 133000 patients...
# Processed 133100 patients...
# Processed 133200 patients...
# Processed 133300 patients...
# Processed 133400 patients...
# Processed 133500 patients...
# Processed 133600 patients...
# Processed 133700 patients...
# Processed 133800 patients...
# Processed 133900 patients...
# Processed 134000 patients...
# Processed 134100 patients...
# Processed 134200 patients...
# Processed 134300 patients...
# Processed 134400 patients...
# Processed 134500 patients...
# Processed 134600 patients...
# Processed 134700 patients...
# Processed 134800 patients...
# Processed 134900 patients...
# Processed 135000 patients...
# Processed 135100 patients...
# Processed 135200 patients...
# Processed 135300 patients...
# Processed 135400 patients...
# Processed 135500 patients...
# Processed 135600 patients...
# Processed 135700 patients...
# Processed 135800 patients...
# Processed 135900 patients...
# Processed 136000 patients...
# Processed 136100 patients...
# Processed 136200 patients...
# Processed 136300 patients...
# Processed 136400 patients...
# Processed 136500 patients...
# Processed 136600 patients...
# Processed 136700 patients...
# Processed 136800 patients...
# Processed 136900 patients...
# Processed 137000 patients...
# Processed 137100 patients...
# Processed 137200 patients...
# Processed 137300 patients...
# Processed 137400 patients...
# Processed 137500 patients...
# Processed 137600 patients...
# Processed 137700 patients...
# Processed 137800 patients...
# Processed 137900 patients...
# Processed 138000 patients...
# Processed 138100 patients...
# Processed 138200 patients...
# Processed 138300 patients...
# Processed 138400 patients...
# Processed 138500 patients...
# Processed 138600 patients...
# Processed 138700 patients...
# Processed 138800 patients...
# Processed 138900 patients...
# Processed 139000 patients...
# Processed 139100 patients...
# Processed 139200 patients...
# Processed 139300 patients...
# Processed 139400 patients...
# Processed 139500 patients...
# Processed 139600 patients...
# Processed 139700 patients...
# Processed 139800 patients...
# Processed 139900 patients...
# Processed 140000 patients...
# Processed 140100 patients...
# Processed 140200 patients...
# Processed 140300 patients...
# Processed 140400 patients...
# Processed 140500 patients...
# Processed 140600 patients...
# Processed 140700 patients...
# Processed 140800 patients...
# Processed 140900 patients...
# Processed 141000 patients...
# Processed 141100 patients...
# Processed 141200 patients...
# Processed 141300 patients...
# Processed 141400 patients...
# Processed 141500 patients...
# Processed 141600 patients...
# Processed 141700 patients...
# Processed 141800 patients...
# Processed 141900 patients...
# Processed 142000 patients...
# Processed 142100 patients...
# Processed 142200 patients...
# Processed 142300 patients...
# Processed 142400 patients...
# Processed 142500 patients...
# Processed 142600 patients...
# Processed 142700 patients...
# Processed 142800 patients...
# Processed 142900 patients...
# Processed 143000 patients...
# Processed 143100 patients...
# Processed 143200 patients...
# Processed 143300 patients...
# Processed 143400 patients...
# Processed 143500 patients...
# Processed 143600 patients...
# Processed 143700 patients...
# Processed 143800 patients...
# Processed 143900 patients...
# Processed 144000 patients...
# Processed 144100 patients...
# Processed 144200 patients...
# Processed 144300 patients...
# Processed 144400 patients...
# Processed 144500 patients...
# Processed 144600 patients...
# Processed 144700 patients...
# Processed 144800 patients...
# Processed 144900 patients...
# Processed 145000 patients...
# Processed 145100 patients...
# Processed 145200 patients...
# Processed 145300 patients...
# Processed 145400 patients...
# Processed 145500 patients...
# Processed 145600 patients...
# Processed 145700 patients...
# Processed 145800 patients...
# Processed 145900 patients...
# Processed 146000 patients...
# Processed 146100 patients...
# Processed 146200 patients...
# Processed 146300 patients...
# Processed 146400 patients...
# Processed 146500 patients...
# Processed 146600 patients...
# Processed 146700 patients...
# Processed 146800 patients...
# Processed 146900 patients...
# Processed 147000 patients...
# Processed 147100 patients...
# Processed 147200 patients...
# Processed 147300 patients...
# Processed 147400 patients...
# Processed 147500 patients...
# Processed 147600 patients...
# Processed 147700 patients...
# Processed 147800 patients...
# Processed 147900 patients...
# Processed 148000 patients...
# Processed 148100 patients...
# Processed 148200 patients...
# Processed 148300 patients...
# Processed 148400 patients...
# Processed 148500 patients...
# Processed 148600 patients...
# Processed 148700 patients...
# Processed 148800 patients...
# Processed 148900 patients...
# Processed 149000 patients...
# Processed 149100 patients...
# Processed 149200 patients...
# Processed 149300 patients...
# Processed 149400 patients...
# Processed 149500 patients...
# Processed 149600 patients...
# Processed 149700 patients...
# Processed 149800 patients...
# Processed 149900 patients...
# Processed 150000 patients...
# Processed 150100 patients...
# Processed 150200 patients...
# Processed 150300 patients...
# Processed 150400 patients...
# Processed 150500 patients...
# Processed 150600 patients...
# Processed 150700 patients...
# Processed 150800 patients...
# Processed 150900 patients...
# Processed 151000 patients...
# Processed 151100 patients...
# Processed 151200 patients...
# Processed 151300 patients...
# Processed 151400 patients...
# Processed 151500 patients...
# Processed 151600 patients...
# Processed 151700 patients...
# Processed 151800 patients...
# Processed 151900 patients...
# Processed 152000 patients...
# Processed 152100 patients...
# Processed 152200 patients...
# Processed 152300 patients...
# Processed 152400 patients...
# Processed 152500 patients...
# Processed 152600 patients...
# Processed 152700 patients...
# Processed 152800 patients...
# Processed 152900 patients...
# Processed 153000 patients...
# Processed 153100 patients...
# Processed 153200 patients...
# Processed 153300 patients...
# Processed 153400 patients...
# Processed 153500 patients...
# Processed 153600 patients...
# Processed 153700 patients...
# Processed 153800 patients...
# Processed 153900 patients...
# Processed 154000 patients...
# Processed 154100 patients...
# Processed 154200 patients...
# Processed 154300 patients...
# Processed 154400 patients...
# Processed 154500 patients...
# Processed 154600 patients...
# Processed 154700 patients...
# Processed 154800 patients...
# Processed 154900 patients...
# Processed 155000 patients...
# Processed 155100 patients...
# Processed 155200 patients...
# Processed 155300 patients...
# Processed 155400 patients...
# Processed 155500 patients...
# Processed 155600 patients...
# Processed 155700 patients...
# Processed 155800 patients...
# Processed 155900 patients...
# Processed 156000 patients...
# Processed 156100 patients...
# Processed 156200 patients...
# Processed 156300 patients...
# Processed 156400 patients...
# Processed 156500 patients...
# Processed 156600 patients...
# Processed 156700 patients...
# Processed 156800 patients...
# Processed 156900 patients...
# Processed 157000 patients...
# Processed 157100 patients...
# Processed 157200 patients...
# Processed 157300 patients...
# Processed 157400 patients...
# Processed 157500 patients...
# Processed 157600 patients...
# Processed 157700 patients...
# Processed 157800 patients...
# Processed 157900 patients...
# Processed 158000 patients...
# Processed 158100 patients...
# Processed 158200 patients...
# Processed 158300 patients...
# Processed 158400 patients...
# Processed 158500 patients...
# Processed 158600 patients...
# Processed 158700 patients...
# Processed 158800 patients...
# Processed 158900 patients...
# Processed 159000 patients...
# Processed 159100 patients...
# Processed 159200 patients...
# Processed 159300 patients...
# Processed 159400 patients...
# Processed 159500 patients...
# Processed 159600 patients...
# Processed 159700 patients...
# Processed 159800 patients...
# Processed 159900 patients...
# Processed 160000 patients...
# Processed 160100 patients...
# Processed 160200 patients...
# Processed 160300 patients...
# Processed 160400 patients...
# Processed 160500 patients...
# Processed 160600 patients...
# Processed 160700 patients...
# Processed 160800 patients...
# Processed 160900 patients...
# Processed 161000 patients...
# Processed 161100 patients...
# Processed 161200 patients...
# Processed 161300 patients...
# Processed 161400 patients...
# Processed 161500 patients...
# Processed 161600 patients...
# Processed 161700 patients...
# Processed 161800 patients...
# Processed 161900 patients...
# Processed 162000 patients...
# Processed 162100 patients...
# Processed 162200 patients...
# Processed 162300 patients...
# Processed 162400 patients...
# Processed 162500 patients...
# Processed 162600 patients...
# Processed 162700 patients...
# Processed 162800 patients...
# Processed 162900 patients...
# Processed 163000 patients...
# Processed 163100 patients...
# Processed 163200 patients...
# Processed 163300 patients...
# Processed 163400 patients...
# Processed 163500 patients...
# Processed 163600 patients...
# Processed 163700 patients...
# Processed 163800 patients...
# Processed 163900 patients...
# Processed 164000 patients...
# Processed 164100 patients...
# Processed 164200 patients...
# Processed 164300 patients...
# Processed 164400 patients...
# Processed 164500 patients...
# Processed 164600 patients...
# Processed 164700 patients...
# Processed 164800 patients...
# Processed 164900 patients...
# Processed 165000 patients...
# Processed 165100 patients...
# Processed 165200 patients...
# Processed 165300 patients...
# Processed 165400 patients...
# Processed 165500 patients...
# Processed 165600 patients...
# Processed 165700 patients...
# Processed 165800 patients...
# Processed 165900 patients...
# Processed 166000 patients...
# Processed 166100 patients...
# Processed 166200 patients...
# Processed 166300 patients...
# Processed 166400 patients...
# Processed 166500 patients...
# Processed 166600 patients...
# Processed 166700 patients...
# Processed 166800 patients...
# Processed 166900 patients...
# Processed 167000 patients...
# Processed 167100 patients...
# Processed 167200 patients...
# Processed 167300 patients...
# Processed 167400 patients...
# Processed 167500 patients...
# Processed 167600 patients...
# Processed 167700 patients...
# Processed 167800 patients...
# Processed 167900 patients...
# Processed 168000 patients...
# Processed 168100 patients...
# Processed 168200 patients...
# Processed 168300 patients...
# Processed 168400 patients...
# Processed 168500 patients...
# Processed 168600 patients...
# Processed 168700 patients...
# Processed 168800 patients...
# ...
# Processed 261900 patients...
# Processed 262000 patients...
# Processed 262100 patients...
# Processed 262200 patients...
# Processed 262300 patients...
# Processed 262400 patients...
# Processed 262500 patients...
# Processed 262600 patients...
# Processed 262700 patients...
# Processed 262800 patients...
# Processed 262900 patients...
# Processed 263000 patients...
# Processed 263100 patients...
# Processed 263200 patients...
# Processed 263300 patients...
# Processed 263400 patients...
# Processed 263500 patients...
# Processed 263600 patients...
# Processed 263700 patients...
# Processed 263800 patients...
# Processed 263900 patients...
# Processed 264000 patients...
# Processed 264100 patients...
# Processed 264200 patients...
# Processed 264300 patients...
# Processed 264400 patients...
# Processed 264500 patients...
# Processed 264600 patients...
# Processed 264700 patients...
# Processed 264800 patients...
# Processed 264900 patients...
# Processed 265000 patients...
# Processed 265100 patients...
# Processed 265200 patients...
# Processed 265300 patients...
# Processed 265400 patients...
# Processed 265500 patients...
# Processed 265600 patients...
# Processed 265700 patients...
# Processed 265800 patients...
# Processed 265900 patients...
# Processed 266000 patients...
# Processed 266100 patients...
# Processed 266200 patients...
# Processed 266300 patients...
# Processed 266400 patients...
# Processed 266500 patients...
# Processed 266600 patients...
# Processed 266700 patients...
# Processed 266800 patients...
# Processed 266900 patients...
# Processed 267000 patients...
# Processed 267100 patients...
# Processed 267200 patients...
# Processed 267300 patients...
# Processed 267400 patients...
# Processed 267500 patients...
# Processed 267600 patients...
# Processed 267700 patients...
# Processed 267800 patients...
# Processed 267900 patients...
# Processed 268000 patients...
# Processed 268100 patients...
# Processed 268200 patients...
# Processed 268300 patients...
# Processed 268400 patients...
# Processed 268500 patients...
# Processed 268600 patients...
# Processed 268700 patients...
# Processed 268800 patients...
# Processed 268900 patients...
# Processed 269000 patients...
# Processed 269100 patients...
# Processed 269200 patients...
# Processed 269300 patients...
# Processed 269400 patients...
# Processed 269500 patients...
# Processed 269600 patients...
# Processed 269700 patients...
# Processed 269800 patients...
# Processed 269900 patients...
# Processed 270000 patients...
# Processed 270100 patients...
# Processed 270200 patients...
# Processed 270300 patients...
# Processed 270400 patients...
# Processed 270500 patients...
# Processed 270600 patients...
# Processed 270700 patients...
# Processed 270800 patients...
# Processed 270900 patients...
# Processed 271000 patients...
# Processed 271100 patients...
# Processed 271200 patients...
# Processed 271300 patients...
# Processed 271400 patients...
# Processed 271500 patients...
# Processed 271600 patients...
# Processed 271700 patients...
# Processed 271800 patients...
# Processed 271900 patients...
# Processed 272000 patients...
# Processed 272100 patients...
# Processed 272200 patients...
# Processed 272300 patients...
# Processed 272400 patients...
# Processed 272500 patients...
# Processed 272600 patients...
# Processed 272700 patients...
# Processed 272800 patients...
# Processed 272900 patients...
# Processed 273000 patients...
# Processed 273100 patients...
# Processed 273200 patients...
# Processed 273300 patients...
# Processed 273400 patients...
# Processed 273500 patients...
# Processed 273600 patients...
# Processed 273700 patients...
# Processed 273800 patients...
# Processed 273900 patients...
# Processed 274000 patients...
# Processed 274100 patients...
# Processed 274200 patients...
# Processed 274300 patients...
# Processed 274400 patients...
# Processed 274500 patients...
# Processed 274600 patients...
# Processed 274700 patients...
# Processed 274800 patients...
# Processed 274900 patients...
# Processed 275000 patients...
# Processed 275100 patients...
# Processed 275200 patients...
# Processed 275300 patients...
# Processed 275400 patients...
# Processed 275500 patients...
# Processed 275600 patients...
# Processed 275700 patients...
# Processed 275800 patients...
# Processed 275900 patients...
# Processed 276000 patients...
# Processed 276100 patients...
# Processed 276200 patients...
# Processed 276300 patients...
# Processed 276400 patients...
# Processed 276500 patients...
# Processed 276600 patients...
# Processed 276700 patients...
# Processed 276800 patients...
# Processed 276900 patients...
# Processed 277000 patients...
# Processed 277100 patients...
# Processed 277200 patients...
# Processed 277300 patients...
# Processed 277400 patients...
# Processed 277500 patients...
# Processed 277600 patients...
# Processed 277700 patients...
# Processed 277800 patients...
# Processed 277900 patients...
# Processed 278000 patients...
# Processed 278100 patients...
# Processed 278200 patients...
# Processed 278300 patients...
# Processed 278400 patients...
# Processed 278500 patients...
# Processed 278600 patients...
# Processed 278700 patients...
# Processed 278800 patients...
# Processed 278900 patients...
# Processed 279000 patients...
# Processed 279100 patients...
# Processed 279200 patients...
# Processed 279300 patients...
# Processed 279400 patients...
# Processed 279500 patients...
# Processed 279600 patients...
# Processed 279700 patients...
# Processed 279800 patients...
# Processed 279900 patients...
# Processed 280000 patients...
# Processed 280100 patients...
# Processed 280200 patients...
# Processed 280300 patients...
# Processed 280400 patients...
# Processed 280500 patients...
# Processed 280600 patients...
# Processed 280700 patients...
# Processed 280800 patients...
# Processed 280900 patients...
# Processed 281000 patients...
# Processed 281100 patients...
# Processed 281200 patients...
# Processed 281300 patients...
# Processed 281400 patients...
# Processed 281500 patients...
# Processed 281600 patients...
# Processed 281700 patients...
# Processed 281800 patients...
# Processed 281900 patients...
# Processed 282000 patients...
# Processed 282100 patients...
# Processed 282200 patients...
# Processed 282300 patients...
# Processed 282400 patients...
# Processed 282500 patients...
# Processed 282600 patients...
# Processed 282700 patients...
# Processed 282800 patients...
# Processed 282900 patients...
# Processed 283000 patients...
# Processed 283100 patients...
# Processed 283200 patients...
# Processed 283300 patients...
# Processed 283400 patients...
# Processed 283500 patients...
# Processed 283600 patients...
# Processed 283700 patients...
# Processed 283800 patients...
# Processed 283900 patients...
# Processed 284000 patients...
# Processed 284100 patients...
# Processed 284200 patients...
# Processed 284300 patients...
# Processed 284400 patients...
# Processed 284500 patients...
# Processed 284600 patients...
# Processed 284700 patients...
# Processed 284800 patients...
# Processed 284900 patients...
# Processed 285000 patients...
# Processed 285100 patients...
# Processed 285200 patients...
# Processed 285300 patients...
# Processed 285400 patients...
# Processed 285500 patients...
# Processed 285600 patients...
# Processed 285700 patients...
# Processed 285800 patients...
# Processed 285900 patients...
# Processed 286000 patients...
# Processed 286100 patients...
# Processed 286200 patients...
# Processed 286300 patients...
# Processed 286400 patients...
# Processed 286500 patients...
# Processed 286600 patients...
# Processed 286700 patients...
# Processed 286800 patients...
# Processed 286900 patients...
# Processed 287000 patients...
# Processed 287100 patients...
# Processed 287200 patients...
# Processed 287300 patients...
# Processed 287400 patients...
# Processed 287500 patients...
# Processed 287600 patients...
# Processed 287700 patients...
# Processed 287800 patients...
# Processed 287900 patients...
# Processed 288000 patients...
# Processed 288100 patients...
# Processed 288200 patients...
# Processed 288300 patients...
# Processed 288400 patients...
# Processed 288500 patients...
# Processed 288600 patients...
# Processed 288700 patients...
# Processed 288800 patients...
# Processed 288900 patients...
# Processed 289000 patients...
# Processed 289100 patients...
# Processed 289200 patients...
# Processed 289300 patients...
# Processed 289400 patients...
# Processed 289500 patients...
# Processed 289600 patients...
# Processed 289700 patients...
# Processed 289800 patients...
# Processed 289900 patients...
# Processed 290000 patients...
# Processed 290100 patients...
# Processed 290200 patients...
# Processed 290300 patients...
# Processed 290400 patients...
# Processed 290500 patients...
# Processed 290600 patients...
# Processed 290700 patients...
# Processed 290800 patients...
# Processed 290900 patients...
# Processed 291000 patients...
# Processed 291100 patients...
# Processed 291200 patients...
# Processed 291300 patients...
# Processed 291400 patients...
# Processed 291500 patients...
# Processed 291600 patients...
# Processed 291700 patients...
# Processed 291800 patients...
# Processed 291900 patients...
# Processed 292000 patients...
# Processed 292100 patients...
# Processed 292200 patients...
# Processed 292300 patients...
# Processed 292400 patients...
# Processed 292500 patients...
# Processed 292600 patients...
# Processed 292700 patients...
# Processed 292800 patients...
# Processed 292900 patients...
# Processed 293000 patients...
# Processed 293100 patients...
# Processed 293200 patients...
# Processed 293300 patients...
# Processed 293400 patients...
# Processed 293500 patients...
# Processed 293600 patients...
# Processed 293700 patients...
# Processed 293800 patients...
# Processed 293900 patients...
# Processed 294000 patients...
# Processed 294100 patients...
# Processed 294200 patients...
# Processed 294300 patients...
# Processed 294400 patients...
# Processed 294500 patients...
# Processed 294600 patients...
# Processed 294700 patients...
# Processed 294800 patients...
# Processed 294900 patients...
# Processed 295000 patients...
# Processed 295100 patients...
# Processed 295200 patients...
# Processed 295300 patients...
# Processed 295400 patients...
# Processed 295500 patients...
# Processed 295600 patients...
# Processed 295700 patients...
# Processed 295800 patients...
# Processed 295900 patients...
# Processed 296000 patients...
# Processed 296100 patients...
# Processed 296200 patients...
# Processed 296300 patients...
# Processed 296400 patients...
# Processed 296500 patients...
# Processed 296600 patients...
# Processed 296700 patients...
# Processed 296800 patients...
# Processed 296900 patients...
# Processed 297000 patients...
# Processed 297100 patients...
# Processed 297200 patients...
# Processed 297300 patients...
# Processed 297400 patients...
# Processed 297500 patients...
# Processed 297600 patients...
# Processed 297700 patients...
# Processed 297800 patients...
# Processed 297900 patients...
# Processed 298000 patients...
# Processed 298100 patients...
# Processed 298200 patients...
# Processed 298300 patients...
# Processed 298400 patients...
# Processed 298500 patients...
# Processed 298600 patients...
# Processed 298700 patients...
# Processed 298800 patients...
# Processed 298900 patients...
# Processed 299000 patients...
# Processed 299100 patients...
# Processed 299200 patients...
# Processed 299300 patients...
# Processed 299400 patients...
# Processed 299500 patients...
# Processed 299600 patients...
# Processed 299700 patients...
# Processed 299800 patients...
# Processed 299900 patients...
# Processed 300000 patients...
# Processed 300100 patients...
# Processed 300200 patients...
# Processed 300300 patients...
# Processed 300400 patients...
# Processed 300500 patients...
# Processed 300600 patients...
# Processed 300700 patients...
# Processed 300800 patients...
# Processed 300900 patients...
# Processed 301000 patients...
# Processed 301100 patients...
# Processed 301200 patients...
# Processed 301300 patients...
# Processed 301400 patients...
# Processed 301500 patients...
# Processed 301600 patients...
# Processed 301700 patients...
# Processed 301800 patients...
# Processed 301900 patients...
# Processed 302000 patients...
# Processed 302100 patients...
# Processed 302200 patients...
# Processed 302300 patients...
# Processed 302400 patients...
# Processed 302500 patients...
# Processed 302600 patients...
# Processed 302700 patients...
# Processed 302800 patients...
# Processed 302900 patients...
# Processed 303000 patients...
# Processed 303100 patients...
# Processed 303200 patients...
# Processed 303300 patients...
# Processed 303400 patients...
# Processed 303500 patients...
# Processed 303600 patients...
# Processed 303700 patients...
# Processed 303800 patients...
# Processed 303900 patients...
# Processed 304000 patients...
# Processed 304100 patients...
# Processed 304200 patients...
# Processed 304300 patients...
# Processed 304400 patients...
# Processed 304500 patients...
# Processed 304600 patients...
# Processed 304700 patients...
# Processed 304800 patients...
# Processed 304900 patients...
# Processed 305000 patients...
# Processed 305100 patients...
# Processed 305200 patients...
# Processed 305300 patients...
# Processed 305400 patients...
# Processed 305500 patients...
# Processed 305600 patients...
# Processed 305700 patients...
# Processed 305800 patients...
# Processed 305900 patients...
# Processed 306000 patients...
# Processed 306100 patients...
# Processed 306200 patients...
# Processed 306300 patients...
# Processed 306400 patients...
# Processed 306500 patients...
# Processed 306600 patients...
# Processed 306700 patients...
# Processed 306800 patients...
# Processed 306900 patients...
# Processed 307000 patients...
# Processed 307100 patients...
# Processed 307200 patients...
# Processed 307300 patients...
# Processed 307400 patients...
# Processed 307500 patients...
# Processed 307600 patients...
# Processed 307700 patients...
# Processed 307800 patients...
# Processed 307900 patients...
# Processed 308000 patients...
# Processed 308100 patients...
# Processed 308200 patients...
# Processed 308300 patients...
# Processed 308400 patients...
# Processed 308500 patients...
# Processed 308600 patients...
# Processed 308700 patients...
# Processed 308800 patients...
# Processed 308900 patients...
# Processed 309000 patients...
# Processed 309100 patients...
# Processed 309200 patients...
# Processed 309300 patients...
# Processed 309400 patients...
# Processed 309500 patients...
# Processed 309600 patients...
# Processed 309700 patients...
# Processed 309800 patients...
# Processed 309900 patients...
# Processed 310000 patients...
# Processed 310100 patients...
# Processed 310200 patients...
# Processed 310300 patients...
# Processed 310400 patients...
# Processed 310500 patients...
# Processed 310600 patients...
# Processed 310700 patients...
# Processed 310800 patients...
# Processed 310900 patients...
# Processed 311000 patients...
# Processed 311100 patients...
# Processed 311200 patients...
# Processed 311300 patients...
# Processed 311400 patients...
# Processed 311500 patients...
# Processed 311600 patients...
# Processed 311700 patients...
# Processed 311800 patients...
# Processed 311900 patients...
# Processed 312000 patients...
# Processed 312100 patients...
# Processed 312200 patients...
# Processed 312300 patients...
# Processed 312400 patients...
# Processed 312500 patients...
# Processed 312600 patients...
# Processed 312700 patients...
# Processed 312800 patients...
# Processed 312900 patients...
# Processed 313000 patients...
# Processed 313100 patients...
# Processed 313200 patients...
# Processed 313300 patients...
# Processed 313400 patients...
# Processed 313500 patients...
# Processed 313600 patients...
# Processed 313700 patients...
# Processed 313800 patients...
# Processed 313900 patients...
# Processed 314000 patients...
# Processed 314100 patients...
# Processed 314200 patients...
# Processed 314300 patients...
# Processed 314400 patients...
# Processed 314500 patients...
# Processed 314600 patients...
# Processed 314700 patients...
# Processed 314800 patients...
# Processed 314900 patients...
# Processed 315000 patients...
# Processed 315100 patients...
# Processed 315200 patients...
# Processed 315300 patients...
# Processed 315400 patients...
# ============================================================
# BENCHMARK RESULTS
# ============================================================
# Data filtering time: 4.05 seconds
# Datetime conversion time: 0.15 seconds
# Processing time: 6812.07 seconds
# Total time: 6816.28 seconds
# Processed patients: 315460
# Valid admissions: 229931
# Readmission rate: 0.203
# Avg conditions per admission: 12.6
# Avg procedures per admission: 2.9
# Avg drugs per admission: 52.9

# %% [markdown]
# ## set_task() operations after reading multiple labevents

# %%
from pyhealth.tasks import InHospitalMortalityMIMIC4
start_time = time.perf_counter()
task = InHospitalMortalityMIMIC4()
sample_dataset = dataset.set_task(task, num_workers=4)
end_time = time.perf_counter()
set_task_time = end_time - start_time
print(f"Set task time: {set_task_time:.2f} seconds")
# Out:
# Setting task InHospitalMortalityMIMIC4 for mimic4 base dataset...
# Collecting global event dataframe...
# Collected dataframe with shape: (147119785, 44)
# Generating samples with 4 worker(s)...
# Generating samples for InHospitalMortalityMIMIC4 with 4 workers
# Collecting samples for InHospitalMortalityMIMIC4 from 4 workers: 100%|██████████| 315460/315460 [17:49<00:00, 294.87it/s]
# Label mortality vocab: {0: 0, 1: 1}
# Processing samples: 100%|██████████| 236532/236532 [02:07<00:00, 1861.04it/s]
# Generated 236532 samples for task InHospitalMortalityMIMIC4
# Set task time: 2236.55 seconds

# %% [markdown]
# ### Cleaned versions for line counting comparisons:

# %%
import pandas as pd
import time
from datetime import datetime
import pandas as pd
import time

path_to_massive_lab_events_table = "/srv/local/data/MIMIC-IV/2.0/hosp/labevents.csv"
path_to_massive_admissions_table = "/srv/local/data/MIMIC-IV/2.0/hosp/admissions.csv"
path_to_massive_diagnoses_table = "/srv/local/data/MIMIC-IV/2.0/hosp/diagnoses_icd.csv"
path_to_massive_procedures_table = "/srv/local/data/MIMIC-IV/2.0/hosp/procedures_icd.csv"
path_to_massive_prescriptions_table = "/srv/local/data/MIMIC-IV/2.0/hosp/prescriptions.csv"
path_to_massive_patients_table = "/srv/local/data/MIMIC-IV/2.0/hosp/patients.csv"

lab_df = pd.read_csv(path_to_massive_lab_events_table)
adm_df = pd.read_csv(path_to_massive_admissions_table)
diag_df = pd.read_csv(path_to_massive_diagnoses_table)
proc_df = pd.read_csv(path_to_massive_procedures_table)
presc_df = pd.read_csv(path_to_massive_prescriptions_table)
pat_df = pd.read_csv(path_to_massive_patients_table)

def benchmark_mimic_processing(adm_df, diag_df, proc_df, presc_df, patients_df, n=1000):
    """
    Benchmark MIMIC-IV data processing for readmission prediction task.
    
    Args:
        adm_df: Admissions dataframe
        diag_df: Diagnoses dataframe  
        proc_df: Procedures dataframe
        presc_df: Prescriptions dataframe
        patients_df: Patients dataframe
        n: Number of patients to process (None = all patients)
    
    Returns:
        DataFrame with processed samples
    """
    print("Starting MIMIC-IV processing benchmark...")
    start_total = time.perf_counter()
    
    # Get patients to process
    if n is None:
        patients_to_process = patients_df['subject_id'].tolist()
        print(f"Processing all {len(patients_to_process)} patients...")
    else:
        patients_to_process = patients_df['subject_id'].head(n).tolist()
        print(f"Processing first {len(patients_to_process)} patients...")
    
    adm_filtered = adm_df[adm_df['subject_id'].isin(patients_to_process)].copy()
    diag_filtered = diag_df[diag_df['subject_id'].isin(patients_to_process)].copy()
    proc_filtered = proc_df[proc_df['subject_id'].isin(patients_to_process)].copy()
    presc_filtered = presc_df[presc_df['subject_id'].isin(patients_to_process)].copy()
    patients_filtered = patients_df[patients_df['subject_id'].isin(patients_to_process)].copy()
    
    adm_filtered['admittime'] = pd.to_datetime(adm_filtered['admittime'])
    adm_filtered['dischtime'] = pd.to_datetime(adm_filtered['dischtime'])
    
    # Process each patient (mimicking the pyhealth task logic)
    start_processing = time.perf_counter()
    
    samples = []
    processed_patients = 0
    
    for subject_id in patients_to_process:
        # Get patient demographics
        patient_demo = patients_filtered[patients_filtered['subject_id'] == subject_id]
        if len(patient_demo) == 0:
            continue
            
        # Skip if under 18 (mimicking the age filter from pyhealth code)
        anchor_age = patient_demo.iloc[0]['anchor_age']
        if anchor_age < 18:
            continue
            
        # Get admissions for this patient, sorted by admit time
        patient_admissions = adm_filtered[
            adm_filtered['subject_id'] == subject_id
        ].sort_values('admittime')
        
        for i, (_, admission) in enumerate(patient_admissions.iterrows()):
            hadm_id = admission['hadm_id']
            admit_time = admission['admittime']
            discharge_time = admission['dischtime']
            
            if pd.isna(discharge_time):
                continue
                
            # Calculate admission duration (skip if <= 12 hours)
            duration_hours = (discharge_time - admit_time).total_seconds() / 3600
            if duration_hours <= 12:
                continue
            
            # Check for readmission within 30 days
            readmission = 0
            if i < len(patient_admissions) - 1:
                next_admission = patient_admissions.iloc[i + 1]
                next_admit_time = next_admission['admittime']
                time_diff_hours = (next_admit_time - discharge_time).total_seconds() / 3600
                
                if time_diff_hours <= 3:  # Skip if too close
                    continue
                    
                readmission = 1 if time_diff_hours < 30 * 24 else 0
            
            # Get events for this admission
            admission_diagnoses = diag_filtered[
                diag_filtered['hadm_id'] == hadm_id
            ]
            admission_procedures = proc_filtered[
                proc_filtered['hadm_id'] == hadm_id
            ]
            admission_prescriptions = presc_filtered[
                presc_filtered['hadm_id'] == hadm_id
            ]
            
            # Create condition codes (mimicking the pyhealth format)
            conditions = []
            if len(admission_diagnoses) > 0:
                conditions = [
                    f"{row['icd_version']}_{row['icd_code']}" 
                    for _, row in admission_diagnoses.iterrows()
                    if pd.notna(row['icd_code'])
                ]
            
            # Create procedure codes
            procedures = []
            if len(admission_procedures) > 0:
                procedures = [
                    f"{row['icd_version']}_{row['icd_code']}" 
                    for _, row in admission_procedures.iterrows()
                    if pd.notna(row['icd_code'])
                ]
            
            # Create drug codes
            drugs = []
            if len(admission_prescriptions) > 0:
                drugs = [
                    f"{row['drug']}" 
                    for _, row in admission_prescriptions.iterrows()
                    if pd.notna(row['drug'])
                ]
            
            # Skip if any category is empty (mimicking pyhealth logic)
            if len(conditions) == 0 or len(procedures) == 0 or len(drugs) == 0:
                continue
            
            samples.append({
                'patient_id': subject_id,
                'admission_id': hadm_id,
                'conditions': conditions,
                'procedures': procedures,
                'drugs': drugs,
                'readmission': readmission,
                'num_conditions': len(conditions),
                'num_procedures': len(procedures),
                'num_drugs': len(drugs)
            })
        
        processed_patients += 1
        if processed_patients % 100 == 0:
            print(f"Processed {processed_patients} patients...")
    
    # Create results dataframe
    results_df = pd.DataFrame(samples)

    return results_df


results = benchmark_mimic_processing(adm_df, diag_df, proc_df, presc_df, pat_df, n=None)

# %%
from pyhealth.tasks import InHospitalMortalityMIMIC4
from pyhealth.datasets import MIMIC4Dataset
root = "/srv/local/data/MIMIC-IV/2.0"
dataset = MIMIC4Dataset(ehr_root=root, ehr_tables=["diagnoses_icd", "procedures_icd", "prescriptions", "labevents"])
task = InHospitalMortalityMIMIC4()
sample_dataset = dataset.set_task(task, num_workers=4)
