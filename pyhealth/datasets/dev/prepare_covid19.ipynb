# %% [markdown]
# This script prepares the COVID-19 dataset for use in the pyhealth package.
#
# URL: https://www.kaggle.com/datasets/tawsifurrahman/covid19-radiography-database

# %%
import os
import sys
import pandas as pd
import json

# %%
raw_data_path = "/srv/local/data/zw12/raw_data/covid19-radiography-database/COVID-19_Radiography_Dataset"

# %%
# !ls $raw_data_path
# Out:
# COVID			    metadata.jsonl	  Viral Pneumonia
# COVID.metadata.xlsx	    Normal		  Viral Pneumonia.metadata.xlsx
# Lung_Opacity		    Normal.metadata.xlsx
# Lung_Opacity.metadata.xlsx  README.md.txt

# %%
covid = pd.DataFrame(pd.read_excel(f"{raw_data_path}/COVID.metadata.xlsx"))
covid
# Out:
#        FILE NAME FORMAT     SIZE  \
# 0        COVID-1    PNG  256*256
# 1        COVID-2    PNG  256*256
# 2        COVID-3    PNG  256*256
# 3        COVID-4    PNG  256*256
# 4        COVID-5    PNG  256*256
# ...          ...    ...      ...
# 3611  COVID-3612    PNG  256*256
# 3612  COVID-3613    PNG  256*256
# 3613  COVID-3614    PNG  256*256
# 3614  COVID-3615    PNG  256*256
# 3615  COVID-3616    PNG  256*256
#
#                                                     URL
# 0     https://sirm.org/category/senza-categoria/covi...
# 1     https://sirm.org/category/senza-categoria/covi...
# 2     https://sirm.org/category/senza-categoria/covi...
# 3     https://sirm.org/category/senza-categoria/covi...
# 4     https://sirm.org/category/senza-categoria/covi...
# ...                                                 ...
# 3611  https://bimcv.cipf.es/bimcv-projects/bimcv-cov...
# 3612  https://bimcv.cipf.es/bimcv-projects/bimcv-cov...
# ...

# %%
print(covid.FORMAT.unique())
print(covid.SIZE.unique())
# Out:
# ['PNG']
# ['256*256']

# %%
covid["FILE NAME"] = covid["FILE NAME"].apply(lambda x: f"COVID/images/{x}.png")
covid["label"] = "COVID"
covid
# Out:
#                         FILE NAME FORMAT     SIZE  \
# 0        COVID/images/COVID-1.png    PNG  256*256
# 1        COVID/images/COVID-2.png    PNG  256*256
# 2        COVID/images/COVID-3.png    PNG  256*256
# 3        COVID/images/COVID-4.png    PNG  256*256
# 4        COVID/images/COVID-5.png    PNG  256*256
# ...                           ...    ...      ...
# 3611  COVID/images/COVID-3612.png    PNG  256*256
# 3612  COVID/images/COVID-3613.png    PNG  256*256
# 3613  COVID/images/COVID-3614.png    PNG  256*256
# 3614  COVID/images/COVID-3615.png    PNG  256*256
# 3615  COVID/images/COVID-3616.png    PNG  256*256
#
#                                                     URL  label
# 0     https://sirm.org/category/senza-categoria/covi...  COVID
# 1     https://sirm.org/category/senza-categoria/covi...  COVID
# 2     https://sirm.org/category/senza-categoria/covi...  COVID
# 3     https://sirm.org/category/senza-categoria/covi...  COVID
# ...

# %%
lung_opacity = pd.DataFrame(pd.read_excel(f"{raw_data_path}/Lung_Opacity.metadata.xlsx"))
lung_opacity
# Out:
#               FILE NAME FORMAT     SIZE  \
# 0        Lung_Opacity-1    PNG  256*256
# 1        Lung_Opacity-2    PNG  256*256
# 2        Lung_Opacity-3    PNG  256*256
# 3        Lung_Opacity-4    PNG  256*256
# 4        Lung_Opacity-5    PNG  256*256
# ...                 ...    ...      ...
# 6007  Lung_Opacity-6008    PNG  256*256
# 6008  Lung_Opacity-6009    PNG  256*256
# 6009  Lung_Opacity-6010    PNG  256*256
# 6010  Lung_Opacity-6011    PNG  256*256
# 6011  Lung_Opacity-6012    PNG  256*256
#
#                                                     URL
# 0     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4     https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...                                                 ...
# 6007  https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...

# %%
print(lung_opacity.FORMAT.unique())
print(lung_opacity.SIZE.unique())
# Out:
# ['PNG']
# ['256*256']

# %%
lung_opacity["FILE NAME"] = lung_opacity["FILE NAME"].apply(lambda x: f"Lung_Opacity/images/{x}.png")
lung_opacity["label"] = "Lung Opacity"
lung_opacity
# Out:
#                                       FILE NAME FORMAT     SIZE  \
# 0        Lung_Opacity/images/Lung_Opacity-1.png    PNG  256*256
# 1        Lung_Opacity/images/Lung_Opacity-2.png    PNG  256*256
# 2        Lung_Opacity/images/Lung_Opacity-3.png    PNG  256*256
# 3        Lung_Opacity/images/Lung_Opacity-4.png    PNG  256*256
# 4        Lung_Opacity/images/Lung_Opacity-5.png    PNG  256*256
# ...                                         ...    ...      ...
# 6007  Lung_Opacity/images/Lung_Opacity-6008.png    PNG  256*256
# 6008  Lung_Opacity/images/Lung_Opacity-6009.png    PNG  256*256
# 6009  Lung_Opacity/images/Lung_Opacity-6010.png    PNG  256*256
# 6010  Lung_Opacity/images/Lung_Opacity-6011.png    PNG  256*256
# 6011  Lung_Opacity/images/Lung_Opacity-6012.png    PNG  256*256
#
#                                                     URL         label
# 0     https://www.kaggle.com/c/rsna-pneumonia-detect...  Lung Opacity
# ...

# %%
normal = pd.DataFrame(pd.read_excel(f"{raw_data_path}/Normal.metadata.xlsx"))
normal
# Out:
#           FILE NAME FORMAT     SIZE  \
# 0          NORMAL-1    PNG  256*256
# 1          NORMAL-2    PNG  256*256
# 2          NORMAL-3    PNG  256*256
# 3          NORMAL-4    PNG  256*256
# 4          NORMAL-5    PNG  256*256
# ...             ...    ...      ...
# 10187  NORMAL-10188    PNG  256*256
# 10188  NORMAL-10189    PNG  256*256
# 10189  NORMAL-10190    PNG  256*256
# 10190  NORMAL-10191    PNG  256*256
# 10191  NORMAL-10192    PNG  256*256
#
#                                                      URL
# 0      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4      https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...                                                  ...
# 10187  https://www.kaggle.com/paultimothymooney/chest...
# 10188  https://www.kaggle.com/paultimothymooney/chest...
# ...

# %%
print(normal.FORMAT.unique())
print(normal.SIZE.unique())
# Out:
# ['PNG']
# ['256*256']

# %%
normal["FILE NAME"] = normal["FILE NAME"].apply(lambda x: x.capitalize())
normal
# Out:
#           FILE NAME FORMAT     SIZE  \
# 0          Normal-1    PNG  256*256
# 1          Normal-2    PNG  256*256
# 2          Normal-3    PNG  256*256
# 3          Normal-4    PNG  256*256
# 4          Normal-5    PNG  256*256
# ...             ...    ...      ...
# 10187  Normal-10188    PNG  256*256
# 10188  Normal-10189    PNG  256*256
# 10189  Normal-10190    PNG  256*256
# 10190  Normal-10191    PNG  256*256
# 10191  Normal-10192    PNG  256*256
#
#                                                      URL
# 0      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4      https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...                                                  ...
# 10187  https://www.kaggle.com/paultimothymooney/chest...
# 10188  https://www.kaggle.com/paultimothymooney/chest...
# ...

# %%
normal["FILE NAME"] = normal["FILE NAME"].apply(lambda x: f"Normal/images/{x}.png")
normal["label"] = "Normal"
normal
# Out:
#                             FILE NAME FORMAT     SIZE  \
# 0          Normal/images/Normal-1.png    PNG  256*256
# 1          Normal/images/Normal-2.png    PNG  256*256
# 2          Normal/images/Normal-3.png    PNG  256*256
# 3          Normal/images/Normal-4.png    PNG  256*256
# 4          Normal/images/Normal-5.png    PNG  256*256
# ...                               ...    ...      ...
# 10187  Normal/images/Normal-10188.png    PNG  256*256
# 10188  Normal/images/Normal-10189.png    PNG  256*256
# 10189  Normal/images/Normal-10190.png    PNG  256*256
# 10190  Normal/images/Normal-10191.png    PNG  256*256
# 10191  Normal/images/Normal-10192.png    PNG  256*256
#
#                                                      URL   label
# 0      https://www.kaggle.com/c/rsna-pneumonia-detect...  Normal
# 1      https://www.kaggle.com/c/rsna-pneumonia-detect...  Normal
# 2      https://www.kaggle.com/c/rsna-pneumonia-detect...  Normal
# ...

# %%
viral_pneumonia = pd.DataFrame(pd.read_excel(f"{raw_data_path}/Viral Pneumonia.metadata.xlsx"))
viral_pneumonia
# Out:
#                  FILE NAME FORMAT     SIZE  \
# 0        Viral Pneumonia-1    PNG  256*256
# 1        Viral Pneumonia-2    PNG  256*256
# 2        Viral Pneumonia-3    PNG  256*256
# 3        Viral Pneumonia-4    PNG  256*256
# 4        Viral Pneumonia-5    PNG  256*256
# ...                    ...    ...      ...
# 1340  Viral Pneumonia-1341    PNG  256*256
# 1341  Viral Pneumonia-1342    PNG  256*256
# 1342  Viral Pneumonia-1343    PNG  256*256
# 1343  Viral Pneumonia-1344    PNG  256*256
# 1344  Viral Pneumonia-1345    PNG  256*256
#
#                                                     URL
# 0     https://www.kaggle.com/paultimothymooney/chest...
# 1     https://www.kaggle.com/paultimothymooney/chest...
# 2     https://www.kaggle.com/paultimothymooney/chest...
# 3     https://www.kaggle.com/paultimothymooney/chest...
# 4     https://www.kaggle.com/paultimothymooney/chest...
# ...                                                 ...
# ...

# %%
print(viral_pneumonia.FORMAT.unique())
print(viral_pneumonia.SIZE.unique())
# Out:
# ['PNG']
# ['256*256']

# %%
viral_pneumonia["FILE NAME"] = viral_pneumonia["FILE NAME"].apply(lambda x: f"Viral Pneumonia/images/{x}.png")
viral_pneumonia["label"] = "Viral Pneumonia"
viral_pneumonia
# Out:
#                                             FILE NAME FORMAT     SIZE  \
# 0        Viral Pneumonia/images/Viral Pneumonia-1.png    PNG  256*256
# 1        Viral Pneumonia/images/Viral Pneumonia-2.png    PNG  256*256
# 2        Viral Pneumonia/images/Viral Pneumonia-3.png    PNG  256*256
# 3        Viral Pneumonia/images/Viral Pneumonia-4.png    PNG  256*256
# 4        Viral Pneumonia/images/Viral Pneumonia-5.png    PNG  256*256
# ...                                               ...    ...      ...
# 1340  Viral Pneumonia/images/Viral Pneumonia-1341.png    PNG  256*256
# 1341  Viral Pneumonia/images/Viral Pneumonia-1342.png    PNG  256*256
# 1342  Viral Pneumonia/images/Viral Pneumonia-1343.png    PNG  256*256
# 1343  Viral Pneumonia/images/Viral Pneumonia-1344.png    PNG  256*256
# 1344  Viral Pneumonia/images/Viral Pneumonia-1345.png    PNG  256*256
#
#                                                     URL            label
# ...

# %%
df = pd.concat([covid, lung_opacity, normal, viral_pneumonia], axis=0, ignore_index=True)
df
# Out:
#                                              FILE NAME FORMAT     SIZE  \
# 0                             COVID/images/COVID-1.png    PNG  256*256
# 1                             COVID/images/COVID-2.png    PNG  256*256
# 2                             COVID/images/COVID-3.png    PNG  256*256
# 3                             COVID/images/COVID-4.png    PNG  256*256
# 4                             COVID/images/COVID-5.png    PNG  256*256
# ...                                                ...    ...      ...
# 21160  Viral Pneumonia/images/Viral Pneumonia-1341.png    PNG  256*256
# 21161  Viral Pneumonia/images/Viral Pneumonia-1342.png    PNG  256*256
# 21162  Viral Pneumonia/images/Viral Pneumonia-1343.png    PNG  256*256
# 21163  Viral Pneumonia/images/Viral Pneumonia-1344.png    PNG  256*256
# 21164  Viral Pneumonia/images/Viral Pneumonia-1345.png    PNG  256*256
#
#                                                      URL            label
# ...

# %%
df = df.drop(columns=["FORMAT", "SIZE"])
df.columns = ["path", "label", "url"]
df
# Out:
#                                                   path  \
# 0                             COVID/images/COVID-1.png
# 1                             COVID/images/COVID-2.png
# 2                             COVID/images/COVID-3.png
# 3                             COVID/images/COVID-4.png
# 4                             COVID/images/COVID-5.png
# ...                                                ...
# 21160  Viral Pneumonia/images/Viral Pneumonia-1341.png
# 21161  Viral Pneumonia/images/Viral Pneumonia-1342.png
# 21162  Viral Pneumonia/images/Viral Pneumonia-1343.png
# 21163  Viral Pneumonia/images/Viral Pneumonia-1344.png
# 21164  Viral Pneumonia/images/Viral Pneumonia-1345.png
#
#                                                    label              url
# 0      https://sirm.org/category/senza-categoria/covi...            COVID
# 1      https://sirm.org/category/senza-categoria/covi...            COVID
# 2      https://sirm.org/category/senza-categoria/covi...            COVID
# ...

# %%
for path in df.path:
    assert os.path.isfile(os.path.join(raw_data_path, path))

# %%
df.to_json(f"{raw_data_path}/metadata.jsonl", orient="records", lines=True)

# %%
out = pd.read_json(path_or_buf=f"{raw_data_path}/metadata.jsonl", lines=True)
out
# Out:
#                                                   path  \
# 0                             COVID/images/COVID-1.png
# 1                             COVID/images/COVID-2.png
# 2                             COVID/images/COVID-3.png
# 3                             COVID/images/COVID-4.png
# 4                             COVID/images/COVID-5.png
# ...                                                ...
# 21160  Viral Pneumonia/images/Viral Pneumonia-1341.png
# 21161  Viral Pneumonia/images/Viral Pneumonia-1342.png
# 21162  Viral Pneumonia/images/Viral Pneumonia-1343.png
# 21163  Viral Pneumonia/images/Viral Pneumonia-1344.png
# 21164  Viral Pneumonia/images/Viral Pneumonia-1345.png
#
#                                                    label              url
# 0      https://sirm.org/category/senza-categoria/covi...            COVID
# 1      https://sirm.org/category/senza-categoria/covi...            COVID
# 2      https://sirm.org/category/senza-categoria/covi...            COVID
# ...
