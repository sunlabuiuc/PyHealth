# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/IvaBojic/SleepQA/refs/heads/main/data/agreement/model_agreement.csv')

# %%
df.columns
# Out:
# Index(['q_p1', 'par_1', 'par_2', 'answer_1', 'answer_2', 'score_a_1',
#        'score_p_1', 'score_a_2', 'score_p_2', 'score_a_3', 'score_p_3',
#        'score_a_4', 'score_p_4', 'score_a_5', 'score_p_5'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                 q_p1  \
# 0  what is the recommended amount of caffeine in ...
# 1                  how long should afternoon naps be
# 2  why do i feel tired even when i sleep such lon...
# 3      is sleeping the same as losing consciousness?
# 4      what kind of diet will improve sleep quality?
#
#                                                par_1  \
# 0  a large cup of coffee can have up to 470 mg of...
# 1  daytime sleeping doesn't have to interfere wit...
# 2  even now there's a piece of research done rece...
# 3  treatment for psm often targets the underlying...
# 4  conversely, extending sleep and maintaining a ...
#
#                                                par_2  \
# 0  it is recommended that those who are pregnant ...
# 1  people nap for a variety of reasons. perhaps t...
# 2  instead, recent research suggests that long sl...
# 3  people who have trouble sleeping due to multip...
# 4  it has been well established that high-carbohy...
#
#                                             answer_1  \
# 0                         470 mg of caffeine content
# 1                             as long as 155 minutes
# 2                              i was highly stressed
# 3  can affect our thoughts and emotions and incre...
# 4     low in refined sugar, salt, and saturated fats
#
#                                             answer_2  score_a_1  score_p_1  \
# 0                          16 ounces or less per day          3          4
# 1                                           how long          4          4
# 2  they may feel sleepy or less alert during the ...          4          4
# 3  you can have a concussion even if you do not l...          4          4
# 4                                      mediterranean          3          3
#
#    score_a_2  score_p_2  score_a_3  score_p_3  score_a_4  score_p_4  \
# 0          3          4          3          3          2          4
# 1          1          4          4          4          4          4
# 2          4          4          4          4          4          4
# 3          4          4          4          4          4          4
# 4          3          3          3          3          3          3
#
#    score_a_5  score_p_5
# 0          3          1
# 1          4          1
# 2          1          2
# 3          4          2
# 4          3          3

# %%
search_string = 'coffee'
columns_to_search = ['q_p1', 'par_1', 'par_2', 'answer_1', 'answer_2']

mask = df[columns_to_search].apply(lambda x: x.str.contains(search_string, na=False)).any(axis=1)

result_df = df[mask]
print(result_df)
# Out:
#                                                   q_p1  \
# 0    what is the recommended amount of caffeine in ...
# 1                    how long should afternoon naps be
# 31            why does coffee make you feel more alert
# 67                        does coffee affect my sleep?
# 84   what is the latest time for the consumption of...
# 87                  how long is appropriate for a nap?
# 100  can i switch from coffee to sodas to keep myse...
# 113  is it okay to consume a lot of caffeine if i'm...
# 130  will switching from coffee to matcha help me w...
# 143  if i don't drink coffee throughout the whole d...
# 144              is it okay to drink coffee before bed
#
#                                                  par_1  \
# 0    a large cup of coffee can have up to 470 mg of...
# 1    daytime sleeping doesn't have to interfere wit...
# 31   coffee drinking is widespread, especially in t...
# 67   it's out in the open your hamstring hurts, let...
# 84   however, establishing regular times to fall as...
# 87   people nap for a variety of reasons. perhaps t...
# 100  coffee drinking is widespread, especially in t...
# 113  up to 400 milligrams of caffeine per day - the...
# 130  coffee and many types of tea contain caffeine....
# 143  this wearables experience changed me, maybe mo...
# 144  although coffee increases alertness, it has li...
#
#                                                  par_2  \
# 0    it is recommended that those who are pregnant ...
# 1    people nap for a variety of reasons. perhaps t...
# 31   coffee promotes alertness and reduces tirednes...
# 67   unfortunately, these will likely make your sle...
# 84   a large cup of coffee can have up to 470 mg of...
# 87   napping can be refreshing if you're short on s...
# 100  this wearables experience changed me, maybe mo...
# 113  different people have different sensitivity le...
# 130  as a result, turning to coffee to fix the effe...
# 143  although coffee increases alertness, it has li...
# 144  another healthy sleep tip is to make sure your...
#
#                                               answer_1  \
# 0                           470 mg of caffeine content
# 1                               as long as 155 minutes
# 31                            sleepy rather than alert
# 67                       my kid does this in his sleep
# 84                                    about 30 minutes
# 87                                            how long
# 100  many people use coffee as part of their mornin...
# 113                    considered safe for most people
# 130  important not to rely on caffeine at the expen...
# 143                      i would allow her more leeway
# 144  studies show that drinking coffee within the s...
#
#                                               answer_2  score_a_1  score_p_1  \
# 0                            16 ounces or less per day          3          4
# 1                                             how long          4          4
# 31   by blocking adenosine receptors and preventing...          2          2
# 67   coffee has the ability to disrupt sleep even w...          2          2
# 84                            six hours before bedtime          3          2
# 87    less than 30 minutes and a maximum of 60 minutes          2          2
# 100                      i would allow her more leeway          4          4
# 113  this is especially relevant if you do not regu...          1          4
# 130  turning to coffee to fix the effects of sleep ...          4          4
# 143                      you might be sleep - deprived          4          4
# 144                   four to six hours before bedtime          1          1
#
#      score_a_2  score_p_2  score_a_3  score_p_3  score_a_4  score_p_4  \
# 0            3          4          3          3          2          4
# 1            1          4          4          4          4          4
# 31           2          2          2          2          2          2
# 67           2          2          2          2          2          2
# 84           2          2          2          2          2          2
# 87           2          2          2          2          2          2
# 100          4          4          1          4          1          4
# 113          1          4          4          4          1          4
# 130          4          4          4          4          4          4
# 143          4          4          4          4          4          4
# 144          1          1          1          1          1          1
#
#      score_a_5  score_p_5
# 0            3          1
# 1            4          1
# 31           2          3
# 67           2          2
# 84           2          2
# 87           2          2
# 100          4          4
# 113          4          4
# 130          4          4
# 143          4          2
# 144          1          3

# %%
result_df.head()
# Out:
#                                                  q_p1  \
# 0   what is the recommended amount of caffeine in ...
# 1                   how long should afternoon naps be
# 31           why does coffee make you feel more alert
# 67                       does coffee affect my sleep?
# 84  what is the latest time for the consumption of...
#
#                                                 par_1  \
# 0   a large cup of coffee can have up to 470 mg of...
# 1   daytime sleeping doesn't have to interfere wit...
# 31  coffee drinking is widespread, especially in t...
# 67  it's out in the open your hamstring hurts, let...
# 84  however, establishing regular times to fall as...
#
#                                                 par_2  \
# 0   it is recommended that those who are pregnant ...
# 1   people nap for a variety of reasons. perhaps t...
# 31  coffee promotes alertness and reduces tirednes...
# 67  unfortunately, these will likely make your sle...
# 84  a large cup of coffee can have up to 470 mg of...
#
#                          answer_1  \
# 0      470 mg of caffeine content
# 1          as long as 155 minutes
# 31       sleepy rather than alert
# 67  my kid does this in his sleep
# 84               about 30 minutes
#
#                                              answer_2  score_a_1  score_p_1  \
# 0                           16 ounces or less per day          3          4
# 1                                            how long          4          4
# 31  by blocking adenosine receptors and preventing...          2          2
# 67  coffee has the ability to disrupt sleep even w...          2          2
# 84                           six hours before bedtime          3          2
#
#     score_a_2  score_p_2  score_a_3  score_p_3  score_a_4  score_p_4  \
# 0           3          4          3          3          2          4
# 1           1          4          4          4          4          4
# 31          2          2          2          2          2          2
# 67          2          2          2          2          2          2
# 84          2          2          2          2          2          2
#
#     score_a_5  score_p_5
# 0           3          1
# 1           4          1
# 31          2          3
# 67          2          2
# 84          2          2

# %%
from pyhealth.datasets.sleepQA import SleepQADataset
from pyhealth.tasks.SearchSleepQAQuestions import SearchSleepQAQuestions

# %%
from pathlib import Path

# %%
path = Path(__file__).parent.parent.parent
ds = SleepQADataset(root=path, config_path=path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 path = Path(__file__).parent.parent.parent
#       2 ds = SleepQADataset(root=path, config_path=path)
#
# NameError: name '__file__' is not defined
