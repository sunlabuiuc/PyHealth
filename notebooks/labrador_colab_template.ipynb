# %% [markdown]
# # Labrador Option2 Colab Template\n用于快速复现、测试与消融。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
print(os.listdir('/content/drive/MyDrive/cs598_dl_for_healthcare'))
#before running this, link the dataset to your own google drive's cs598_dl_for_healthcare folder.
# Out:
# ['Labrador data set']

# %%
DATA_ROOT = "/content/drive/MyDrive/cs598_dl_for_healthcare/Labrador data set"
CORE_DIR = os.path.join(DATA_ROOT, "Core")
HOSP_DIR = os.path.join(DATA_ROOT, "HOSP")
ICU_DIR = os.path.join(DATA_ROOT, "ICU")

print(DATA_ROOT)
print(os.listdir(CORE_DIR))
print(os.listdir(HOSP_DIR)[:10])
print(os.listdir(ICU_DIR)[:10])
# Out:
# /content/drive/MyDrive/cs598_dl_for_healthcare/Labrador data set
# ['patients.csv.gz', 'admissions.csv.gz', 'transfers.csv.gz', 'index.html']
# ['LICENSE.txt', 'd_hcpcs.csv.gz', 'd_labitems.csv.gz', 'diagnoses_icd.csv.gz', 'drgcodes.csv.gz', 'd_icd_procedures.csv.gz', 'd_icd_diagnoses.csv.gz', 'emar.csv.gz', 'hcpcsevents.csv.gz', 'microbiologyevents.csv.gz']
# ['chartevents.csv.gz', 'datetimeevents.csv.gz', 'icustays.csv.gz', 'inputevents.csv.gz', 'outputevents.csv.gz', 'procedureevents.csv.gz', 'SHA256SUMS.txt', 'index.html', 'd_items.csv.gz']

# %%
# !python -m pip install -U pip
# !pip install pyhealth pytest ruff

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落

# %%
from getpass import getpass
import os

GITHUB_USER = "coconight01" #change to user's github name
GITHUB_TOKEN = getpass("GitHub token: ") #PAT token
os.environ["GITHUB_USER"] = GITHUB_USER
os.environ["GITHUB_TOKEN"] = GITHUB_TOKEN

# !git clone https://$GITHUB_USER:$GITHUB_TOKEN@github.com/coconight01/CS598_FInal_Project.git
# %cd /content/CS598_FInal_Project
# !pwd
# Out:
# GitHub token: ··········
# fatal: destination path 'CS598_FInal_Project' already exists and is not an empty directory.
# /content/CS598_FInal_Project
# /content/CS598_FInal_Project
# /content/CS598_FInal_Project
# /content/CS598_FInal_Project

# %%
# %cd /content/CS598_FInal_Project
import os, sys
sys.path.insert(0, os.getcwd())
print(sys.path[0])
# Out:
# /content/CS598_FInal_Project
# /content/CS598_FInal_Project

# %%
# !find . -maxdepth 2 -type f | sed -n '1,120p'
# !find pyhealth/models -maxdepth 2 -type f | sort | sed -n '1,80p'
# !find tests -maxdepth 2 -type f | sort | sed -n '1,80p'
# !find examples -maxdepth 2 -type f | sort | sed -n '1,80p'
# Out:
# ./README.md
# ./CS598_FInal_Project/README.md
# ./notebooks/labrador_colab_template.ipynb
# ./docs/PYHEALTH_ENV_AND_COLAB_ZH.md
# ./.pytest_cache/README.md
# ./.pytest_cache/.gitignore
# ./.pytest_cache/CACHEDIR.TAG
# ./scripts/labrador_preflight.sh
# ./.git/packed-refs
# ./.git/HEAD
# ./.git/config
# ./.git/index
# ./.git/description
# ./templates/labrador_option2_pr_template.md
# ./examples/mimic4_mortality_labrador.py
# ./tests/test_labrador.py
# pyhealth/models/__init__.py
# pyhealth/models/labrador.py
# tests/__pycache__/test_labrador.cpython-312-pytest-8.4.2.pyc
# tests/test_labrador.py
# examples/mimic4_mortality_labrador.py

# %%
# !cp /content/CS598_FInal_Project/pyhealth/models/labrador.py \
    /usr/local/lib/python3.12/dist-packages/pyhealth/models/labrador.py
# !PYTHONPATH=/content/CS598_FInal_Project pytest tests/test_labrador.py -q
# Out:
# ..EEEEE                                                                  [100%]
# ==================================== ERRORS ====================================
# ____________ ERROR at setup of TestLabradorModel.test_instantiation ____________
# file /content/CS598_FInal_Project/tests/test_labrador.py, line 39
#       def test_instantiation(self, mock_dataset):
# file /content/CS598_FInal_Project/tests/test_labrador.py, line 13
#   @pytest.fixture
#   def mock_dataset(mocker):
# E       fixture 'mocker' not found
# >       available fixtures: anyio_backend, anyio_backend_name, anyio_backend_options, cache, capfd, capfdbinary, caplog, capsys, capsysbinary, capteesys, doctest_namespace, free_tcp_port, free_tcp_port_factory, free_udp_port, free_udp_port_factory, mock_dataset, monkeypatch, pytestconfig, record_property, record_testsuite_property, record_xml_attribute, recwarn, tmp_path, tmp_path_factory, tmpdir, tmpdir_factory
# ...

# %%
# !find . -maxdepth 4 -type f | sort | sed -n '1,200p'
# !find pyhealth -maxdepth 3 -type f | sort | sed -n '1,120p'
# !python -c "import sys; print(sys.path[:3])"
# Out:
# ./CS598_FInal_Project/docs/api/models.rst
# ./CS598_FInal_Project/docs/PYHEALTH_ENV_AND_COLAB_ZH.md
# ./CS598_FInal_Project/examples/mimic4_mortality_labrador.py
# ./CS598_FInal_Project/.git/config
# ./CS598_FInal_Project/.git/description
# ./CS598_FInal_Project/.git/HEAD
# ./CS598_FInal_Project/.git/hooks/applypatch-msg.sample
# ./CS598_FInal_Project/.git/hooks/commit-msg.sample
# ./CS598_FInal_Project/.git/hooks/fsmonitor-watchman.sample
# ./CS598_FInal_Project/.git/hooks/post-update.sample
# ./CS598_FInal_Project/.git/hooks/pre-applypatch.sample
# ./CS598_FInal_Project/.git/hooks/pre-commit.sample
# ./CS598_FInal_Project/.git/hooks/pre-merge-commit.sample
# ./CS598_FInal_Project/.git/hooks/prepare-commit-msg.sample
# ./CS598_FInal_Project/.git/hooks/pre-push.sample
# ./CS598_FInal_Project/.git/hooks/pre-rebase.sample
# ./CS598_FInal_Project/.git/hooks/pre-receive.sample
# ./CS598_FInal_Project/.git/hooks/push-to-checkout.sample
# ./CS598_FInal_Project/.git/hooks/update.sample
# ...

# %%
# !python -c "import os; print(os.path.exists('/content/CS598_FInal_Project/pyhealth/models/labrador.py'))"
# !python -c "import importlib.util; print(importlib.util.find_spec('pyhealth')); print(importlib.util.find_spec('pyhealth.models')); print(importlib.util.find_spec('pyhealth.models.labrador'))"
# Out:
# True
# ModuleSpec(name='pyhealth', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ca035238aa0>, origin='/usr/local/lib/python3.12/dist-packages/pyhealth/__init__.py', submodule_search_locations=['/usr/local/lib/python3.12/dist-packages/pyhealth'])
# ModuleSpec(name='pyhealth.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ca034f42b10>, origin='/usr/local/lib/python3.12/dist-packages/pyhealth/models/__init__.py', submodule_search_locations=['/usr/local/lib/python3.12/dist-packages/pyhealth/models'])
# 2026-04-09 08:40:29.581114: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !bash scripts/labrador_preflight.sh
# Out:
# bash: scripts/labrador_preflight.sh: No such file or directory

# %%
# !python examples/mimic4_mortality_labrador.py
# Out:
# python3: can't open file '/content/examples/mimic4_mortality_labrador.py': [Errno 2] No such file or directory

# %% [markdown]
# ## 记录结果\n请把不同配置的 accuracy / roc_auc 填表，后续用于 PR 与视频。
