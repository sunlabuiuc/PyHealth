# %% [markdown]
# # Read Cache

# %%
import os
import pandas as pd

# %%
os.chdir("../../../")
print(f"The current working directory is: {os.getcwd()}")
# Out:
# The current working directory is: /home/wp14

# %%
df = pd.read_parquet("pyhealth_cache_labs/012dadb7-77c0-575b-aef5-f1d7fee6a314/global_event_df.parquet")

# %%
df.shape
# Out:
# (118975491, 33)
